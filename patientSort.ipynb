# %%
import os
import re
import pydicom
import numpy as np
from PIL import Image

def convert_and_rename_dicom_to_png(work_dir):
    """
    For each patient subfolder in work_dir:
      - Finds only unprefixed .dcm files
      - Sorts them by their Z-position
      - Renames them to 0001_<orig>.dcm, 0002_<orig>.dcm, …
      - Converts to 0001_<orig_base>.png (only if not already there)
    """
    for pid in sorted(os.listdir(work_dir)):
        pid_folder = os.path.join(work_dir, pid)
        if not os.path.isdir(pid_folder):
            continue

        slices = []
        for fname in os.listdir(pid_folder):
            if not fname.lower().endswith('.dcm'):
                continue
            # skip files that already have a 4-digit prefix
            if re.match(r'^\d{4}_', fname):
                continue

            full_path = os.path.join(pid_folder, fname)
            try:
                ds = pydicom.dcmread(full_path)
                z = float(ds.ImagePositionPatient[2])
                slices.append((z, fname, ds))
            except Exception as e:
                print(f"Skipping {full_path}: {e}")

        if not slices:
            print(f"Patient {pid}: no new DICOMs to process")
            continue

        # 2) Sort by Z
        slices.sort(key=lambda x: x[0])

        # 3) Rename + convert
        for idx, (_, fname, ds) in enumerate(slices, start=1):
            prefix = f"{idx:04d}_"
            old_dcm = os.path.join(pid_folder, fname)
            new_dcm = os.path.join(pid_folder, prefix + fname)

            # Rename the .dcm on disk
            os.rename(old_dcm, new_dcm)

            # Build PNG path
            base, _ = os.path.splitext(fname)
            png_name = f"{prefix}{base}.png"
            png_path = os.path.join(pid_folder, png_name)

            # Only convert if the PNG doesn't already exist
            if not os.path.exists(png_path):
                arr = ds.pixel_array.astype(np.float32)
                intercept = getattr(ds, 'RescaleIntercept', 0.0)
                slope     = getattr(ds, 'RescaleSlope',     1.0)
                arr = arr * slope + intercept

                pmin, pmax = arr.min(), arr.max()
                if pmax > pmin:
                    arr = (arr - pmin) / (pmax - pmin) * 255.0
                arr = arr.astype(np.uint8)

                Image.fromarray(arr).save(png_path)

        print(f"Patient {pid}: processed {len(slices)} file(s)")

WORK_DIR = './patient_images_0_1000'
convert_and_rename_dicom_to_png(WORK_DIR)
# Out:
# Patient ID_00526c11: processed 84 file(s)
# Patient ID_00859e11: processed 32 file(s)
# Patient ID_0086733c: processed 28 file(s)
# Patient ID_00e30393: processed 31 file(s)
# Patient ID_013cf2a2: processed 44 file(s)
# Patient ID_02bdea77: processed 30 file(s)
# Patient ID_03e3ed6d: processed 45 file(s)
# Patient ID_0402b53e: processed 30 file(s)
# Patient ID_046b584b: processed 141 file(s)
# Patient ID_047b307a: processed 44 file(s)
# Patient ID_048d5624: processed 34 file(s)
# Patient ID_04a7b221: processed 33 file(s)
# Patient ID_04fcd3da: processed 178 file(s)
# Patient ID_0515ef2f: processed 28 file(s)
# Patient ID_0531c34e: processed 34 file(s)
# Patient ID_05bb1f88: processed 32 file(s)
# Patient ID_05d3ffff: processed 42 file(s)
# Patient ID_05fa237b: processed 65 file(s)
# Patient ID_06185aa5: processed 34 file(s)
# Patient ID_06b045bf: processed 247 file(s)
# Patient ID_06c7d632: processed 28 file(s)
# Patient ID_06edbec1: processed 34 file(s)
# Patient ID_0762da12: processed 40 file(s)
# Patient ID_07741131: processed 33 file(s)
# Patient ID_0781672a: processed 30 file(s)
# Patient ID_083f644d: processed 46 file(s)
# Patient ID_08a89e8e: processed 32 file(s)
# Patient ID_090f8b79: processed 32 file(s)
# Patient ID_09409fc7: processed 36 file(s)
# Patient ID_09422b4a: processed 80 file(s)
# Patient ID_095c522a: processed 64 file(s)
# Patient ID_09681778: processed 29 file(s)
# Patient ID_09bf6329: processed 116 file(s)
# Patient ID_09e88cd7: processed 33 file(s)
# Patient ID_0a01a6c4: processed 32 file(s)
# Patient ID_0a0ef792: processed 44 file(s)
# Patient ID_0a125878: processed 32 file(s)
# Patient ID_0a360fb1: processed 48 file(s)
# Patient ID_0ad31a65: processed 36 file(s)
# Patient ID_0b902b36: processed 36 file(s)
# Patient ID_0baadb05: processed 40 file(s)
# Patient ID_0be3fa40: processed 32 file(s)
# Patient ID_0c3208e4: processed 30 file(s)
# Patient ID_0cd1512c: processed 37 file(s)
# Patient ID_0cddb2a2: processed 30 file(s)
# Patient ID_0ce7ddbc: processed 132 file(s)
# Patient ID_0d1c1633: processed 40 file(s)
# Patient ID_0d58c8e1: processed 36 file(s)
# Patient ID_0e386dca: processed 32 file(s)
# Patient ID_0e780605: processed 33 file(s)
# Patient ID_0e91f449: processed 36 file(s)
# Patient ID_0f2a00e5: processed 59 file(s)
# Patient ID_0f38cdb1: processed 32 file(s)
# Patient ID_0f561411: processed 69 file(s)
# Patient ID_0fbd7809: processed 52 file(s)
# Patient ID_0ff437c4: processed 100 file(s)
# Patient ID_102767c7: processed 33 file(s)
# Patient ID_10398493: processed 32 file(s)
# Patient ID_106d2f99: processed 32 file(s)
# Patient ID_10b9a991: processed 69 file(s)
# Patient ID_10beb45f: processed 28 file(s)
# Patient ID_112f4511: processed 102 file(s)
# Patient ID_114513b0: processed 39 file(s)
# Patient ID_116c8896: processed 46 file(s)
# Patient ID_12874243: processed 36 file(s)
# Patient ID_1290e471: processed 34 file(s)
# Patient ID_12bd4f33: processed 40 file(s)
# Patient ID_134f661b: processed 36 file(s)
# Patient ID_13d85b1f: processed 36 file(s)
# Patient ID_141acd90: processed 32 file(s)
# Patient ID_14353770: processed 44 file(s)
# Patient ID_1439ac67: processed 33 file(s)
# Patient ID_1495daf7: processed 70 file(s)
# Patient ID_1534f4c8: processed 35 file(s)
# Patient ID_153e43bf: processed 136 file(s)
# Patient ID_1596b352: processed 28 file(s)
# Patient ID_16332433: processed 31 file(s)
# Patient ID_16a23d6a: processed 36 file(s)
# Patient ID_16f719a5: processed 38 file(s)
# Patient ID_17027b61: processed 32 file(s)
# Patient ID_18747540: processed 34 file(s)
# Patient ID_189d891f: processed 35 file(s)
# Patient ID_18a14c7e: processed 37 file(s)
# Patient ID_18b1bd8d: processed 30 file(s)
# Patient ID_191f3e4e: processed 35 file(s)
# Patient ID_19248abb: processed 36 file(s)
# Patient ID_193acffb: processed 28 file(s)
# Patient ID_194db451: processed 38 file(s)
# Patient ID_1974581d: processed 28 file(s)
# Patient ID_19edd875: processed 88 file(s)
# Patient ID_1a23c93a: processed 32 file(s)
# Patient ID_1a6a5070: processed 24 file(s)
# Patient ID_1a6d2d97: processed 32 file(s)
# Patient ID_1aae01db: processed 40 file(s)
# Patient ID_1afd9477: processed 116 file(s)
# Patient ID_1b402138: processed 32 file(s)
# Patient ID_1b5b14ad: processed 36 file(s)
# Patient ID_1c312e63: processed 34 file(s)
# Patient ID_1c8bddb0: processed 40 file(s)
# Patient ID_1c9c37ad: processed 28 file(s)
# Patient ID_1cbe2853: processed 32 file(s)
# Patient ID_1cc5c8d4: processed 44 file(s)
# Patient ID_1dbe2d50: processed 39 file(s)
# Patient ID_1e006bbc: processed 32 file(s)
# Patient ID_1e10ccf2: processed 31 file(s)
# Patient ID_1e433917: processed 35 file(s)
# Patient ID_1e74903a: processed 112 file(s)
# Patient ID_1f15256c: processed 42 file(s)
# Patient ID_1f806a1a: processed 36 file(s)
# Patient ID_1f8667af: processed 68 file(s)
# Patient ID_1f8fa544: processed 36 file(s)
# Patient ID_1fa0e188: processed 36 file(s)
# Patient ID_2003f57e: processed 31 file(s)
# Patient ID_2086c7f3: processed 173 file(s)
# Patient ID_20a06aa9: processed 30 file(s)
# Patient ID_20c2b489: processed 31 file(s)
# Patient ID_2160b72b: processed 45 file(s)
# Patient ID_21ae9427: processed 36 file(s)
# Patient ID_21e3372e: processed 28 file(s)
# Patient ID_22389cfd: processed 32 file(s)
# Patient ID_22427ffe: processed 32 file(s)
# Patient ID_22686923: processed 40 file(s)
# Patient ID_229f6a42: processed 40 file(s)
# Patient ID_22c909b4: processed 32 file(s)
# Patient ID_2319d650: processed 142 file(s)
# Patient ID_2349a958: processed 36 file(s)
# Patient ID_234cf552: processed 44 file(s)
# Patient ID_2378f0b7: processed 64 file(s)
# Patient ID_23fe5436: processed 28 file(s)
# Patient ID_24645857: processed 34 file(s)
# Patient ID_24965b9e: processed 33 file(s)
# Patient ID_24df80e7: processed 384 file(s)
# Patient ID_24f9bfc5: processed 40 file(s)
# Patient ID_2565057f: processed 32 file(s)
# Patient ID_25ed6070: processed 44 file(s)
# Patient ID_275616cd: processed 35 file(s)
# Patient ID_27a5a7f2: processed 37 file(s)
# Patient ID_27afd104: processed 36 file(s)
# Patient ID_27b1f19b: processed 32 file(s)
# Patient ID_27b6ff99: processed 32 file(s)
# Patient ID_27ddc408: processed 59 file(s)
# Patient ID_2802e154: processed 30 file(s)
# Patient ID_28039788: processed 35 file(s)
# Patient ID_28622235: processed 64 file(s)
# Patient ID_28701613: processed 44 file(s)
# Patient ID_28733cfd: processed 32 file(s)
# Patient ID_288e230e: processed 51 file(s)
# Patient ID_29137d4e: processed 34 file(s)
# Patient ID_29222f4e: processed 64 file(s)
# Patient ID_2922ed6e: processed 70 file(s)
# Patient ID_29233b7b: processed 80 file(s)
# Patient ID_292c63fc: processed 34 file(s)
# Patient ID_29528b54: processed 35 file(s)
# Patient ID_2993fb73: processed 102 file(s)
# Patient ID_29d2772a: processed 32 file(s)
# Patient ID_2aa56078: processed 30 file(s)
# Patient ID_2b35cfb8: processed 52 file(s)
# Patient ID_2b714f1a: processed 40 file(s)
# Patient ID_2b75e193: processed 103 file(s)
# Patient ID_2b8741c5: processed 122 file(s)
# Patient ID_2b8838d6: processed 36 file(s)
# Patient ID_2bc99005: processed 32 file(s)
# Patient ID_2bf60fbd: processed 48 file(s)
# Patient ID_2cc29d59: processed 30 file(s)
# Patient ID_2cfc710f: processed 34 file(s)
# Patient ID_2d44d017: processed 245 file(s)
# Patient ID_2d509aa7: processed 74 file(s)
# Patient ID_2df3deb9: processed 33 file(s)
# Patient ID_2e55ccb9: processed 106 file(s)
# Patient ID_2e9eb3f8: processed 42 file(s)
# Patient ID_2ea889e3: processed 178 file(s)
# Patient ID_2ecaabfe: processed 264 file(s)
# Patient ID_2efbb26d: processed 88 file(s)
# Patient ID_2f02b88c: processed 34 file(s)
# Patient ID_2f08ea2c: processed 32 file(s)
# Patient ID_2f527103: processed 40 file(s)
# Patient ID_300a120b: processed 29 file(s)
# Patient ID_30ca28d8: processed 60 file(s)
# Patient ID_30d19531: processed 32 file(s)
# Patient ID_31015256: processed 32 file(s)
# Patient ID_3110c9de: processed 30 file(s)
# Patient ID_31652e46: processed 256 file(s)
# Patient ID_31d1554f: processed 64 file(s)
# Patient ID_320a1703: processed 36 file(s)
# Patient ID_32150121: processed 72 file(s)
# Patient ID_325f8c88: processed 189 file(s)
# Patient ID_32c07778: processed 28 file(s)
# Patient ID_32f4a8ed: processed 40 file(s)
# Patient ID_331a0a71: processed 32 file(s)
# Patient ID_339d9651: processed 34 file(s)
# Patient ID_33a6fa45: processed 40 file(s)
# Patient ID_33c23df3: processed 33 file(s)
# Patient ID_33d65356: processed 36 file(s)
# Patient ID_34375431: processed 40 file(s)
# Patient ID_34480fbb: processed 28 file(s)
# Patient ID_345c66cd: processed 36 file(s)
# Patient ID_34ac4fd9: processed 28 file(s)
# Patient ID_34adcc3e: processed 68 file(s)
# Patient ID_34be79b0: processed 36 file(s)
# Patient ID_3557cc57: processed 32 file(s)
# Patient ID_35a154ec: processed 32 file(s)
# Patient ID_35cacafa: processed 32 file(s)
# Patient ID_361eb5ee: processed 44 file(s)
# Patient ID_3661d884: processed 33 file(s)
# Patient ID_36c4424f: processed 32 file(s)
# Patient ID_36e5050e: processed 40 file(s)
# Patient ID_3750087a: processed 132 file(s)
# Patient ID_37804bff: processed 48 file(s)
# Patient ID_380f3b4a: processed 35 file(s)
# Patient ID_38797203: processed 35 file(s)
# Patient ID_38f8dd68: processed 36 file(s)
# Patient ID_3956b469: processed 170 file(s)
# Patient ID_3956f565: processed 40 file(s)
# Patient ID_397b1ec6: processed 32 file(s)
# Patient ID_39c814dd: processed 169 file(s)
# Patient ID_3a3c2570: processed 36 file(s)
# Patient ID_3a6b2a4a: processed 40 file(s)
# Patient ID_3abd9afd: processed 32 file(s)
# Patient ID_3b323613: processed 139 file(s)
# Patient ID_3bbf73cb: processed 40 file(s)
# Patient ID_3bc85ab1: processed 37 file(s)
# Patient ID_3be63ca2: processed 66 file(s)
# Patient ID_3c10f9dd: processed 32 file(s)
# Patient ID_3c39aa25: processed 34 file(s)
# Patient ID_3c4bab8c: processed 40 file(s)
# Patient ID_3c7d692a: processed 32 file(s)
# Patient ID_3d041e67: processed 32 file(s)
# Patient ID_3d19ab45: processed 78 file(s)
# Patient ID_3d6d5c25: processed 34 file(s)
# Patient ID_3d9d3a41: processed 36 file(s)
# Patient ID_3e0ecc51: processed 32 file(s)
# Patient ID_3e11ee12: processed 63 file(s)
# Patient ID_3eaaa176: processed 66 file(s)
# Patient ID_3f0af787: processed 38 file(s)
# Patient ID_3f2366c7: processed 54 file(s)
# Patient ID_3f244bf8: processed 83 file(s)
# Patient ID_3ff3f64f: processed 32 file(s)
# Patient ID_402555db: processed 116 file(s)
# Patient ID_40500791: processed 36 file(s)
# Patient ID_407b437c: processed 88 file(s)
# Patient ID_408e5a45: processed 44 file(s)
# Patient ID_413a205e: processed 64 file(s)
# Patient ID_41496e62: processed 76 file(s)
# Patient ID_41b580cc: processed 64 file(s)
# Patient ID_41fbad2a: processed 32 file(s)
# Patient ID_421687f2: processed 44 file(s)
# Patient ID_425a04e2: processed 36 file(s)
# Patient ID_42aaa797: processed 32 file(s)
# Patient ID_42ec8de3: processed 44 file(s)
# Patient ID_434057f7: processed 32 file(s)
# Patient ID_434a9402: processed 32 file(s)
# Patient ID_43a937d5: processed 40 file(s)
# Patient ID_43cb6c19: processed 28 file(s)
# Patient ID_445f82bd: processed 68 file(s)
# Patient ID_44aa00c6: processed 40 file(s)
# Patient ID_4572a50a: processed 32 file(s)
# Patient ID_457fb04c: processed 40 file(s)
# Patient ID_45ab53bc: processed 44 file(s)
# Patient ID_462cddb3: processed 144 file(s)
# Patient ID_4631069b: processed 32 file(s)
# Patient ID_464e2d16: processed 53 file(s)
# Patient ID_468db19c: processed 31 file(s)
# Patient ID_46f96b4b: processed 28 file(s)
# Patient ID_474cc974: processed 36 file(s)
# Patient ID_4760870c: processed 32 file(s)
# Patient ID_4820fde0: processed 35 file(s)
# Patient ID_484df4eb: processed 32 file(s)
# Patient ID_488a1f4c: processed 32 file(s)
# Patient ID_4892efc1: processed 36 file(s)
# Patient ID_48b141a3: processed 35 file(s)
# Patient ID_48ea9ffe: processed 28 file(s)
# Patient ID_491ecfc5: processed 35 file(s)
# Patient ID_4941c875: processed 33 file(s)
# Patient ID_49b72d08: processed 65 file(s)
# Patient ID_4a6046d7: processed 32 file(s)
# Patient ID_4a89eaec: processed 64 file(s)
# Patient ID_4a8b7f44: processed 40 file(s)
# Patient ID_4ab8a38c: processed 37 file(s)
# Patient ID_4b0046ad: processed 68 file(s)
# Patient ID_4bc7e34f: processed 69 file(s)
# Patient ID_4bcc8462: processed 30 file(s)
# Patient ID_4bdb4ca4: processed 37 file(s)
# Patient ID_4c5203e4: processed 40 file(s)
# Patient ID_4d117ca6: processed 35 file(s)
# Patient ID_4d50a305: processed 34 file(s)
# Patient ID_4d990362: processed 97 file(s)
# Patient ID_4e017d09: processed 32 file(s)
# Patient ID_4e072077: processed 35 file(s)
# Patient ID_4e50b56c: processed 41 file(s)
# Patient ID_4e8a1468: processed 76 file(s)
# Patient ID_4ecb1803: processed 32 file(s)
# Patient ID_4ed55706: processed 32 file(s)
# Patient ID_4ee06dce: processed 31 file(s)
# Patient ID_4ef5d2c2: processed 37 file(s)
# Patient ID_4f1388ee: processed 157 file(s)
# Patient ID_4f2ef6bd: processed 28 file(s)
# Patient ID_4f69cfc4: processed 71 file(s)
# Patient ID_4f87ed82: processed 280 file(s)
# Patient ID_4fa6c826: processed 36 file(s)
# Patient ID_4fdc5779: processed 71 file(s)
# Patient ID_4fe0762c: processed 34 file(s)
# Patient ID_500d4c17: processed 60 file(s)
# Patient ID_5078baa1: processed 24 file(s)
# Patient ID_50db970d: processed 32 file(s)
# Patient ID_5117f9bf: processed 349 file(s)
# Patient ID_514485c6: processed 36 file(s)
# Patient ID_51d12de3: processed 48 file(s)
# Patient ID_5214af9f: processed 100 file(s)
# Patient ID_5250540f: processed 40 file(s)
# Patient ID_52f5f4c0: processed 38 file(s)
# Patient ID_532343e0: processed 36 file(s)
# Patient ID_538abc9c: processed 37 file(s)
# Patient ID_539b1ea8: processed 40 file(s)
# Patient ID_53a56157: processed 40 file(s)
# Patient ID_54523464: processed 36 file(s)
# Patient ID_54ff9969: processed 43 file(s)
# Patient ID_55179c9f: processed 36 file(s)
# Patient ID_551fb566: processed 40 file(s)
# Patient ID_556bbb81: processed 32 file(s)
# Patient ID_55f41512: processed 74 file(s)
# Patient ID_55fe5ea0: processed 68 file(s)
# Patient ID_562453fd: processed 40 file(s)
# Patient ID_5670297a: processed 29 file(s)
# Patient ID_567a54f7: processed 34 file(s)
# Patient ID_56b481a5: processed 36 file(s)
# Patient ID_57374966: processed 30 file(s)
# Patient ID_574ff0ed: processed 40 file(s)
# Patient ID_57abb053: processed 77 file(s)
# Patient ID_57d2ec05: processed 38 file(s)
# Patient ID_57e2d878: processed 32 file(s)
# Patient ID_580dc795: processed 40 file(s)
# Patient ID_588b05d0: processed 46 file(s)
# Patient ID_58c4b9c9: processed 40 file(s)
# Patient ID_590781ec: processed 32 file(s)
# Patient ID_59293228: processed 33 file(s)
# Patient ID_59449a15: processed 40 file(s)
# Patient ID_5962fb9d: processed 32 file(s)
# Patient ID_596ab7ed: processed 38 file(s)
# Patient ID_599b7c86: processed 40 file(s)
# Patient ID_59cfd681: processed 40 file(s)
# Patient ID_59fc3412: processed 291 file(s)
# Patient ID_5a2f9b4e: processed 33 file(s)
# Patient ID_5a5c48f2: processed 28 file(s)
# Patient ID_5ac1d167: processed 34 file(s)
# Patient ID_5aed7871: processed 104 file(s)
# Patient ID_5b37c199: processed 28 file(s)
# Patient ID_5b557029: processed 66 file(s)
# Patient ID_5babfee6: processed 33 file(s)
# Patient ID_5cddd1a2: processed 28 file(s)
# Patient ID_5d225217: processed 38 file(s)
# Patient ID_5e0abe00: processed 32 file(s)
# Patient ID_5e0cb0fa: processed 38 file(s)
# Patient ID_5e4a8dc5: processed 36 file(s)
# Patient ID_5ebb934e: processed 32 file(s)
# Patient ID_5ecd8190: processed 36 file(s)
# Patient ID_5ee71b4f: processed 36 file(s)
# Patient ID_5f10bb06: processed 40 file(s)
# Patient ID_5f292ef8: processed 40 file(s)
# Patient ID_5fab93e1: processed 40 file(s)
# Patient ID_5fad6382: processed 40 file(s)
# Patient ID_5fc24d8d: processed 32 file(s)
# Patient ID_605b0387: processed 34 file(s)
# Patient ID_6074f71f: processed 28 file(s)
# Patient ID_608fe899: processed 64 file(s)
# Patient ID_60aa8388: processed 28 file(s)
# Patient ID_60dadd86: processed 44 file(s)
# Patient ID_60de2d45: processed 56 file(s)
# Patient ID_61230c87: processed 40 file(s)
# Patient ID_6172a307: processed 40 file(s)
# Patient ID_621617b5: processed 44 file(s)
# Patient ID_621b02fb: processed 68 file(s)
# Patient ID_626bbe7e: processed 62 file(s)
# Patient ID_631bb202: processed 64 file(s)
# Patient ID_6338c4f1: processed 80 file(s)
# Patient ID_63862d24: processed 60 file(s)
# Patient ID_63fc0170: processed 40 file(s)
# Patient ID_6401f47a: processed 30 file(s)
# Patient ID_64135901: processed 36 file(s)
# Patient ID_642e553b: processed 67 file(s)
# Patient ID_643b4943: processed 38 file(s)
# Patient ID_6480f55c: processed 36 file(s)
# Patient ID_64bedb53: processed 32 file(s)
# Patient ID_65068cc1: processed 41 file(s)
# Patient ID_65570143: processed 28 file(s)
# Patient ID_658089c2: processed 36 file(s)
# Patient ID_65ce3fbf: processed 40 file(s)
# Patient ID_65f05a7f: processed 32 file(s)
# Patient ID_66a789d2: processed 35 file(s)
# Patient ID_66de94cd: processed 124 file(s)
# Patient ID_6729fc03: processed 48 file(s)
# Patient ID_672d9eeb: processed 40 file(s)
# Patient ID_673d2622: processed 40 file(s)
# Patient ID_677f38f6: processed 36 file(s)
# Patient ID_67967387: processed 92 file(s)
# Patient ID_679a9829: processed 32 file(s)
# Patient ID_67e3dd2d: processed 67 file(s)
# Patient ID_6832d244: processed 40 file(s)
# Patient ID_6870bde2: processed 80 file(s)
# Patient ID_6920db8a: processed 44 file(s)
# Patient ID_693be4b0: processed 36 file(s)
# Patient ID_694877bd: processed 41 file(s)
# Patient ID_69dc1705: processed 32 file(s)
# Patient ID_6a0e73c3: processed 32 file(s)
# Patient ID_6a1529ae: processed 32 file(s)
# Patient ID_6a47d33a: processed 156 file(s)
# Patient ID_6a656c8c: processed 41 file(s)
# Patient ID_6a954d3e: processed 36 file(s)
# Patient ID_6ae0c0e4: processed 32 file(s)
# Patient ID_6b72349b: processed 34 file(s)
# Patient ID_6b81bd74: processed 64 file(s)
# Patient ID_6b9a6754: processed 28 file(s)
# Patient ID_6bd8a97b: processed 28 file(s)
# Patient ID_6c1e51d3: processed 36 file(s)
# Patient ID_6c200fb9: processed 44 file(s)
# Patient ID_6c4eb5be: processed 32 file(s)
# Patient ID_6c95cb7d: processed 69 file(s)
# Patient ID_6d156aa6: processed 73 file(s)
# Patient ID_6d909bb6: processed 28 file(s)
# Patient ID_6dc616fa: processed 30 file(s)
# Patient ID_6dd8a1f8: processed 72 file(s)
# Patient ID_6e148bb6: processed 28 file(s)
# Patient ID_6e16ad64: processed 36 file(s)
# Patient ID_6e2e88da: processed 35 file(s)
# Patient ID_6e5b4966: processed 36 file(s)
# Patient ID_6e6b5160: processed 74 file(s)
# Patient ID_6e825319: processed 101 file(s)
# Patient ID_6edb3e25: processed 38 file(s)
# Patient ID_6ee3c214: processed 64 file(s)
# Patient ID_6fd208b9: processed 72 file(s)
# Patient ID_7024a509: processed 36 file(s)
# Patient ID_7024db3a: processed 32 file(s)
# Patient ID_71effc3d: processed 32 file(s)
# Patient ID_7207fa95: processed 34 file(s)
# Patient ID_7247a27a: processed 40 file(s)
# Patient ID_72ba98d4: processed 31 file(s)
# Patient ID_72f3abed: processed 32 file(s)
# Patient ID_7427a380: processed 40 file(s)
# Patient ID_747b2d22: processed 41 file(s)
# Patient ID_74a1b5be: processed 39 file(s)
# Patient ID_74e102b8: processed 104 file(s)
# Patient ID_7564de50: processed 28 file(s)
# Patient ID_75656cb3: processed 32 file(s)
# Patient ID_75714feb: processed 40 file(s)
# Patient ID_761ba61f: processed 38 file(s)
# Patient ID_769c4f5a: processed 40 file(s)
# Patient ID_76a9cfba: processed 36 file(s)
# Patient ID_771166b1: processed 40 file(s)
# Patient ID_7739fdb9: processed 36 file(s)
# Patient ID_778967e4: processed 37 file(s)
# Patient ID_782108c8: processed 40 file(s)
# Patient ID_786336c9: processed 36 file(s)
# Patient ID_795755b3: processed 35 file(s)
# Patient ID_79669711: processed 33 file(s)
# Patient ID_7997c82e: processed 32 file(s)
# Patient ID_79c0838b: processed 199 file(s)
# Patient ID_79c52943: processed 32 file(s)
# Patient ID_79d9bab1: processed 31 file(s)
# Patient ID_79f5d8f7: processed 35 file(s)
# Patient ID_7a15e805: processed 33 file(s)
# Patient ID_7a83bc13: processed 28 file(s)
# Patient ID_7a931ed4: processed 32 file(s)
# Patient ID_7a9e8209: processed 64 file(s)
# Patient ID_7adf3447: processed 36 file(s)
# Patient ID_7af8f437: processed 37 file(s)
# Patient ID_7b0527a1: processed 28 file(s)
# Patient ID_7b060526: processed 32 file(s)
# Patient ID_7b26602e: processed 28 file(s)
# Patient ID_7b3aaf8b: processed 34 file(s)
# Patient ID_7b4d1d09: processed 80 file(s)
# Patient ID_7b9a8838: processed 73 file(s)
# Patient ID_7ba59d14: processed 30 file(s)
# Patient ID_7bcf0282: processed 35 file(s)
# Patient ID_7c5d364a: processed 32 file(s)
# Patient ID_7ca17546: processed 60 file(s)
# Patient ID_7d0370ac: processed 39 file(s)
# Patient ID_7d05d937: processed 33 file(s)
# Patient ID_7d3d32cf: processed 28 file(s)
# Patient ID_7d5b36f9: processed 34 file(s)
# Patient ID_7d75d290: processed 40 file(s)
# Patient ID_7d89c44f: processed 40 file(s)
# Patient ID_7df7ad0a: processed 48 file(s)
# Patient ID_7e12098c: processed 30 file(s)
# Patient ID_7e97e16e: processed 32 file(s)
# Patient ID_7eab9495: processed 34 file(s)
# Patient ID_7ed4a54f: processed 42 file(s)
# Patient ID_7f6ee367: processed 32 file(s)
# Patient ID_802aede8: processed 46 file(s)
# Patient ID_8067d3e8: processed 30 file(s)
# Patient ID_806a8589: processed 32 file(s)
# Patient ID_8074f54e: processed 33 file(s)
# Patient ID_80ef001a: processed 44 file(s)
# Patient ID_81031dfb: processed 60 file(s)
# Patient ID_810c8c03: processed 32 file(s)
# Patient ID_814929cb: processed 46 file(s)
# Patient ID_819de77c: processed 30 file(s)
# Patient ID_8227d646: processed 31 file(s)
# Patient ID_825cf2b2: processed 38 file(s)
# Patient ID_829131ae: processed 30 file(s)
# Patient ID_82b32d95: processed 32 file(s)
# Patient ID_8313c071: processed 32 file(s)
# Patient ID_836e19d8: processed 29 file(s)
# Patient ID_83e2fff4: processed 72 file(s)
# Patient ID_83e6bdc7: processed 72 file(s)
# Patient ID_845aa72d: processed 64 file(s)
# Patient ID_8492cc67: processed 60 file(s)
# Patient ID_84cb27c8: processed 34 file(s)
# Patient ID_84e345eb: processed 28 file(s)
# Patient ID_852ffdec: processed 36 file(s)
# Patient ID_85377393: processed 38 file(s)
# Patient ID_86302070: processed 32 file(s)
# Patient ID_86467a1c: processed 35 file(s)
# Patient ID_864a58c9: processed 40 file(s)
# Patient ID_8676cf8c: processed 36 file(s)
# Patient ID_8776abea: processed 30 file(s)
# Patient ID_87ef7072: processed 44 file(s)
# Patient ID_8813490e: processed 36 file(s)
# Patient ID_886ae126: processed 42 file(s)
# Patient ID_8884e2dd: processed 37 file(s)
# Patient ID_88cce19a: processed 28 file(s)
# Patient ID_890089ea: processed 36 file(s)
# Patient ID_89077814: processed 32 file(s)
# Patient ID_891ec6ab: processed 32 file(s)
# Patient ID_8931541c: processed 64 file(s)
# Patient ID_894936f8: processed 31 file(s)
# Patient ID_895a8563: processed 36 file(s)
# Patient ID_8997e646: processed 60 file(s)
# Patient ID_89bdcc3b: processed 32 file(s)
# Patient ID_8a278e5d: processed 39 file(s)
# Patient ID_8a7d528a: processed 32 file(s)
# Patient ID_8a867c75: processed 32 file(s)
# Patient ID_8aa97af1: processed 32 file(s)
# Patient ID_8ae969ac: processed 36 file(s)
# Patient ID_8b01f879: processed 29 file(s)
# Patient ID_8b5fc4f6: processed 32 file(s)
# Patient ID_8bca9b69: processed 48 file(s)
# Patient ID_8bfe6c11: processed 28 file(s)
# Patient ID_8c298617: processed 32 file(s)
# Patient ID_8cc63298: processed 75 file(s)
# Patient ID_8d05b932: processed 28 file(s)
# Patient ID_8d2d5588: processed 32 file(s)
# Patient ID_8d77a804: processed 36 file(s)
# Patient ID_8df20993: processed 34 file(s)
# Patient ID_8e9ba7a2: processed 36 file(s)
# Patient ID_8f8089df: processed 66 file(s)
# Patient ID_905513a4: processed 40 file(s)
# Patient ID_907f00d7: processed 32 file(s)
# Patient ID_9091a7ef: processed 31 file(s)
# Patient ID_90fd6087: processed 32 file(s)
# Patient ID_910167fb: processed 32 file(s)
# Patient ID_9116e504: processed 31 file(s)
# Patient ID_91571425: processed 32 file(s)
# Patient ID_91c16731: processed 36 file(s)
# Patient ID_925ffd44: processed 42 file(s)
# Patient ID_92d6579c: processed 32 file(s)
# Patient ID_9304492f: processed 64 file(s)
# Patient ID_935fe8a4: processed 66 file(s)
# Patient ID_9372b733: processed 39 file(s)
# Patient ID_93806008: processed 285 file(s)
# Patient ID_93aa636f: processed 35 file(s)
# Patient ID_93b150d0: processed 173 file(s)
# Patient ID_9402feb3: processed 38 file(s)
# Patient ID_940311b9: processed 36 file(s)
# Patient ID_9476f262: processed 40 file(s)
# Patient ID_94a74adb: processed 36 file(s)
# Patient ID_95218960: processed 37 file(s)
# Patient ID_9524a2ec: processed 40 file(s)
# Patient ID_9537cb46: processed 28 file(s)
# Patient ID_954d81e2: processed 40 file(s)
# Patient ID_9557fa78: processed 170 file(s)
# Patient ID_95deae29: processed 36 file(s)
# Patient ID_96462e69: processed 60 file(s)
# Patient ID_9660b760: processed 32 file(s)
# Patient ID_96954f6b: processed 34 file(s)
# Patient ID_96f03221: processed 44 file(s)
# Patient ID_9733e86c: processed 36 file(s)
# Patient ID_975457ab: processed 35 file(s)
# Patient ID_97759401: processed 39 file(s)
# Patient ID_97b47cd1: processed 28 file(s)
# Patient ID_9857543b: processed 28 file(s)
# Patient ID_98bad0cd: processed 33 file(s)
# Patient ID_98df6fc3: processed 78 file(s)
# Patient ID_99a527c9: processed 36 file(s)
# Patient ID_99f8e875: processed 141 file(s)
# Patient ID_9a78df90: processed 88 file(s)
# Patient ID_9a807ed6: processed 46 file(s)
# Patient ID_9b2b3fd9: processed 32 file(s)
# Patient ID_9b2ce254: processed 32 file(s)
# Patient ID_9bc2a1ba: processed 28 file(s)
# Patient ID_9c55299b: processed 36 file(s)
# Patient ID_9c6cadfc: processed 28 file(s)
# Patient ID_9c79fc67: processed 32 file(s)
# Patient ID_9ca1fc80: processed 173 file(s)
# Patient ID_9cad3699: processed 36 file(s)
# Patient ID_9d4732f1: processed 32 file(s)
# Patient ID_9d613cb8: processed 34 file(s)
# Patient ID_9eac3f88: processed 56 file(s)
# Patient ID_9ec34a28: processed 30 file(s)
# Patient ID_9eee80a4: processed 32 file(s)
# Patient ID_9f027843: processed 140 file(s)
# Patient ID_a044b66d: processed 34 file(s)
# Patient ID_a065f3ac: processed 34 file(s)
# Patient ID_a06c4a6d: processed 32 file(s)
# Patient ID_a08b5982: processed 80 file(s)
# Patient ID_a0be6fee: processed 68 file(s)
# Patient ID_a0be926e: processed 33 file(s)
# Patient ID_a0f2086d: processed 48 file(s)
# Patient ID_a0f9a12e: processed 30 file(s)
# Patient ID_a102494b: processed 37 file(s)
# Patient ID_a1041905: processed 200 file(s)
# Patient ID_a11e58c7: processed 38 file(s)
# Patient ID_a12018e7: processed 40 file(s)
# Patient ID_a14b61eb: processed 32 file(s)
# Patient ID_a2117aff: processed 28 file(s)
# Patient ID_a213129a: processed 32 file(s)
# Patient ID_a21ccaf5: processed 33 file(s)
# Patient ID_a2255eeb: processed 36 file(s)
# Patient ID_a23fe79b: processed 53 file(s)
# Patient ID_a2d35161: processed 32 file(s)
# Patient ID_a2f3512f: processed 44 file(s)
# Patient ID_a2fe752d: processed 40 file(s)
# Patient ID_a2ffd116: processed 32 file(s)
# Patient ID_a30e75ba: processed 35 file(s)
# Patient ID_a31d97a2: processed 38 file(s)
# Patient ID_a329da04: processed 32 file(s)
# Patient ID_a38c865a: processed 34 file(s)
# Patient ID_a3b0db7b: processed 32 file(s)
# Patient ID_a3bb4e75: processed 52 file(s)
# Patient ID_a4061ddd: processed 36 file(s)
# Patient ID_a40bbd27: processed 32 file(s)
# Patient ID_a46a1fcc: processed 36 file(s)
# Patient ID_a470073a: processed 34 file(s)
# Patient ID_a4780b6d: processed 39 file(s)
# Patient ID_a47978d2: processed 28 file(s)
# Patient ID_a49a5efc: processed 32 file(s)
# Patient ID_a4b7b95b: processed 32 file(s)
# Patient ID_a55d4722: processed 40 file(s)
# Patient ID_a58c61b9: processed 32 file(s)
# Patient ID_a59ca853: processed 38 file(s)
# Patient ID_a5f71e3b: processed 32 file(s)
# Patient ID_a603c877: processed 30 file(s)
# Patient ID_a6466fc7: processed 38 file(s)
# Patient ID_a6584b14: processed 39 file(s)
# Patient ID_a661a555: processed 42 file(s)
# Patient ID_a7d9d319: processed 41 file(s)
# Patient ID_a7eef85b: processed 64 file(s)
# Patient ID_a88550b0: processed 32 file(s)
# Patient ID_a8d0c74d: processed 39 file(s)
# Patient ID_a90855a6: processed 60 file(s)
# Patient ID_a959a93c: processed 32 file(s)
# Patient ID_a95e2a3a: processed 80 file(s)
# Patient ID_a9679497: processed 158 file(s)
# Patient ID_a9a5da1d: processed 32 file(s)
# Patient ID_aa1e0c49: processed 44 file(s)
# Patient ID_aa68fe42: processed 40 file(s)
# Patient ID_aaa193ed: processed 40 file(s)
# Patient ID_ab18679d: processed 32 file(s)
# Patient ID_ab374c63: processed 24 file(s)
# Patient ID_ab7c2a08: processed 30 file(s)
# Patient ID_ab86cd88: processed 32 file(s)
# Patient ID_ac4691db: processed 275 file(s)
# Patient ID_ac55443e: processed 32 file(s)
# Patient ID_ac57e226: processed 84 file(s)
# Patient ID_aca1438c: processed 173 file(s)
# Patient ID_ad40b5f6: processed 40 file(s)
# Patient ID_ad520e68: processed 40 file(s)
# Patient ID_ad5cebfc: processed 50 file(s)
# Patient ID_ad83af8d: processed 35 file(s)
# Patient ID_ae6caaa0: processed 75 file(s)
# Patient ID_ae8edb71: processed 28 file(s)
# Patient ID_ae975af3: processed 62 file(s)
# Patient ID_ae9d2b26: processed 32 file(s)
# Patient ID_af1f6a8a: processed 40 file(s)
# Patient ID_af628585: processed 42 file(s)
# Patient ID_af65b09e: processed 37 file(s)
# Patient ID_af787505: processed 32 file(s)
# Patient ID_afbdc96e: processed 30 file(s)
# Patient ID_afbf985e: processed 48 file(s)
# Patient ID_afd8ebfe: processed 300 file(s)
# Patient ID_b0ac33ab: processed 36 file(s)
# Patient ID_b0d7d2c9: processed 36 file(s)
# Patient ID_b1d5d5e8: processed 32 file(s)
# Patient ID_b1e72399: processed 72 file(s)
# Patient ID_b1ff5bc4: processed 96 file(s)
# Patient ID_b2b40794: processed 32 file(s)
# Patient ID_b2cd8791: processed 130 file(s)
# Patient ID_b2f933fa: processed 156 file(s)
# Patient ID_b31ea623: processed 101 file(s)
# Patient ID_b372d83f: processed 31 file(s)
# Patient ID_b393cba9: processed 56 file(s)
# Patient ID_b3a354f2: processed 28 file(s)
# Patient ID_b3a96be5: processed 30 file(s)
# Patient ID_b47f4fe4: processed 36 file(s)
# Patient ID_b4a5aa19: processed 39 file(s)
# Patient ID_b4dc0fe8: processed 71 file(s)
# Patient ID_b4dcc61a: processed 44 file(s)
# Patient ID_b501522f: processed 32 file(s)
# Patient ID_b54ed8ef: processed 28 file(s)
# Patient ID_b59d1617: processed 32 file(s)
# Patient ID_b5e48ddb: processed 34 file(s)
# Patient ID_b5f2914a: processed 34 file(s)
# Patient ID_b667aeee: processed 30 file(s)
# Patient ID_b66f0b20: processed 40 file(s)
# Patient ID_b6768893: processed 32 file(s)
# Patient ID_b6bc7cb0: processed 128 file(s)
# Patient ID_b6da90a0: processed 32 file(s)
# Patient ID_b789a838: processed 37 file(s)
# Patient ID_b798f160: processed 36 file(s)
# Patient ID_b799ed34: processed 26 file(s)
# Patient ID_b844ff0f: processed 39 file(s)
# Patient ID_b86a8e3a: processed 35 file(s)
# Patient ID_b92b91e9: processed 32 file(s)
# Patient ID_b92eb773: processed 34 file(s)
# Patient ID_b9402657: processed 78 file(s)
# Patient ID_b971b066: processed 39 file(s)
# Patient ID_b9885431: processed 38 file(s)
# Patient ID_b9c3fa70: processed 74 file(s)
# Patient ID_b9c52721: processed 28 file(s)
# Patient ID_b9d80416: processed 44 file(s)
# Patient ID_b9df8c1c: processed 28 file(s)
# Patient ID_ba27c6c5: processed 40 file(s)
# Patient ID_ba281bf8: processed 31 file(s)
# Patient ID_ba404dfe: processed 32 file(s)
# Patient ID_bab0de02: processed 32 file(s)
# Patient ID_bac02f7c: processed 32 file(s)
# Patient ID_bac4bd8e: processed 34 file(s)
# Patient ID_bb18211b: processed 32 file(s)
# Patient ID_bb213878: processed 38 file(s)
# Patient ID_bb74b508: processed 31 file(s)
# Patient ID_bb7fc7d7: processed 38 file(s)
# Patient ID_bbe8008c: processed 33 file(s)
# Patient ID_bc330b3c: processed 110 file(s)
# Patient ID_bd892a1d: processed 32 file(s)
# Patient ID_bdb8ac4f: processed 33 file(s)
# Patient ID_be193483: processed 84 file(s)
# Patient ID_bee66b22: processed 70 file(s)
# Patient ID_bf18ca4a: processed 28 file(s)
# Patient ID_bf3c0b09: processed 37 file(s)
# Patient ID_bf452c8a: processed 32 file(s)
# Patient ID_bf60eac5: processed 36 file(s)
# Patient ID_bf7186f7: processed 34 file(s)
# Patient ID_bf8a3143: processed 32 file(s)
# Patient ID_bfb40203: processed 37 file(s)
# Patient ID_bff3b5c9: processed 32 file(s)
# Patient ID_c029ca17: processed 28 file(s)
# Patient ID_c0a15bcf: processed 34 file(s)
# Patient ID_c0efd0a2: processed 147 file(s)
# Patient ID_c114c2b8: processed 32 file(s)
# Patient ID_c13afed0: processed 73 file(s)
# Patient ID_c1ee6b75: processed 32 file(s)
# Patient ID_c22acceb: processed 70 file(s)
# Patient ID_c23b7634: processed 37 file(s)
# Patient ID_c3448fcc: processed 32 file(s)
# Patient ID_c39f3da7: processed 60 file(s)
# Patient ID_c437190d: processed 120 file(s)
# Patient ID_c4519e23: processed 48 file(s)
# Patient ID_c4b3d0b0: processed 38 file(s)
# Patient ID_c4fdc496: processed 40 file(s)
# Patient ID_c514454e: processed 28 file(s)
# Patient ID_c52cd27e: processed 116 file(s)
# Patient ID_c534919a: processed 32 file(s)
# Patient ID_c57f605b: processed 32 file(s)
# Patient ID_c5875b7f: processed 31 file(s)
# Patient ID_c589a17b: processed 34 file(s)
# Patient ID_c5b9f6a9: processed 147 file(s)
# Patient ID_c5fb4e6e: processed 32 file(s)
# Patient ID_c646ac70: processed 40 file(s)
# Patient ID_c65cd3b8: processed 30 file(s)
# Patient ID_c6cc8ce8: processed 40 file(s)
# Patient ID_c70477c2: processed 36 file(s)
# Patient ID_c7241360: processed 36 file(s)
# Patient ID_c731c09f: processed 40 file(s)
# Patient ID_c76680f2: processed 34 file(s)
# Patient ID_c779109b: processed 32 file(s)
# Patient ID_c7b2c196: processed 373 file(s)
# Patient ID_c7fe5f7f: processed 60 file(s)
# Patient ID_c87e5003: processed 36 file(s)
# Patient ID_c8818678: processed 32 file(s)
# Patient ID_c8c30baf: processed 29 file(s)
# Patient ID_c8c522e0: processed 32 file(s)
# Patient ID_c917f61b: processed 36 file(s)
# Patient ID_c91a524c: processed 32 file(s)
# Patient ID_c9aa068c: processed 75 file(s)
# Patient ID_c9b2d9b3: processed 31 file(s)
# Patient ID_c9c12790: processed 28 file(s)
# Patient ID_c9ff34e5: processed 35 file(s)
# Patient ID_ca0cf17b: processed 32 file(s)
# Patient ID_ca0e1c89: processed 38 file(s)
# Patient ID_caee7821: processed 36 file(s)
# Patient ID_cb852d1e: processed 63 file(s)
# Patient ID_cbddaa3c: processed 252 file(s)
# Patient ID_cc410877: processed 36 file(s)
# Patient ID_cc92853f: processed 32 file(s)
# Patient ID_ccce5f93: processed 40 file(s)
# Patient ID_ccf23e97: processed 38 file(s)
# Patient ID_cd2c8fad: processed 40 file(s)
# Patient ID_cd441cb7: processed 32 file(s)
# Patient ID_cdc9084d: processed 106 file(s)
# Patient ID_ce53ede4: processed 40 file(s)
# Patient ID_ce5bf1be: processed 36 file(s)
# Patient ID_ce5f0b6c: processed 280 file(s)
# Patient ID_ce6af3f4: processed 40 file(s)
# Patient ID_ce7f7c78: processed 40 file(s)
# Patient ID_cec4a149: processed 64 file(s)
# Patient ID_cef99c95: processed 28 file(s)
# Patient ID_cf2d6600: processed 36 file(s)
# Patient ID_cf5caf75: processed 42 file(s)
# Patient ID_cfa46d4d: processed 30 file(s)
# Patient ID_cfa8ad3e: processed 40 file(s)
# Patient ID_cfafc191: processed 28 file(s)
# Patient ID_cfc4cbb1: processed 41 file(s)
# Patient ID_d02f2ee1: processed 30 file(s)
# Patient ID_d035a9fe: processed 32 file(s)
# Patient ID_d051eff4: processed 110 file(s)
# Patient ID_d1037bb6: processed 33 file(s)
# Patient ID_d1150afd: processed 32 file(s)
# Patient ID_d17c5f62: processed 32 file(s)
# Patient ID_d1b16255: processed 29 file(s)
# Patient ID_d1f11939: processed 100 file(s)
# Patient ID_d212e72a: processed 32 file(s)
# Patient ID_d23942c7: processed 36 file(s)
# Patient ID_d2deede6: processed 465 file(s)
# Patient ID_d338249d: processed 40 file(s)
# Patient ID_d343e4d0: processed 90 file(s)
# Patient ID_d350b969: processed 40 file(s)
# Patient ID_d3f0e352: processed 32 file(s)
# Patient ID_d463eef9: processed 34 file(s)
# Patient ID_d4806927: processed 40 file(s)
# Patient ID_d50ddcef: processed 31 file(s)
# Patient ID_d559c35d: processed 34 file(s)
# Patient ID_d55bd9d3: processed 52 file(s)
# Patient ID_d56ba23f: processed 35 file(s)
# Patient ID_d5b9400b: processed 36 file(s)
# Patient ID_d6130fac: processed 151 file(s)
# Patient ID_d6298d10: processed 28 file(s)
# Patient ID_d63e8274: processed 30 file(s)
# Patient ID_d691c6b4: processed 36 file(s)
# Patient ID_d72e08f0: processed 28 file(s)
# Patient ID_d79bbd03: processed 28 file(s)
# Patient ID_d7aef478: processed 32 file(s)
# Patient ID_d7cc90e2: processed 39 file(s)
# Patient ID_d7f1f700: processed 40 file(s)
# Patient ID_d807c567: processed 30 file(s)
# Patient ID_d8409049: processed 36 file(s)
# Patient ID_d864bdc7: processed 36 file(s)
# Patient ID_d8e9de56: processed 60 file(s)
# Patient ID_d978ae79: processed 39 file(s)
# Patient ID_d98583a6: processed 36 file(s)
# Patient ID_d9b6fcb7: processed 71 file(s)
# Patient ID_d9bc5c86: processed 32 file(s)
# Patient ID_d9fb84df: processed 36 file(s)
# Patient ID_d9fc2e0f: processed 31 file(s)
# Patient ID_da25cda3: processed 44 file(s)
# Patient ID_da8db6c5: processed 32 file(s)
# Patient ID_dae32cee: processed 76 file(s)
# Patient ID_daebc87c: processed 36 file(s)
# Patient ID_db291695: processed 32 file(s)
# Patient ID_dbe3acc9: processed 75 file(s)
# Patient ID_dc16f4b2: processed 36 file(s)
# Patient ID_dc63bc96: processed 40 file(s)
# Patient ID_dd158dca: processed 32 file(s)
# Patient ID_dd2f73a3: processed 32 file(s)
# Patient ID_dd477dd7: processed 29 file(s)
# Patient ID_ddf83ca8: processed 41 file(s)
# Patient ID_de23248b: processed 44 file(s)
# Patient ID_de685255: processed 32 file(s)
# Patient ID_de7cbd93: processed 36 file(s)
# Patient ID_debe5ed5: processed 32 file(s)
# Patient ID_ded47654: processed 76 file(s)
# Patient ID_def2db8e: processed 32 file(s)
# Patient ID_df089b9b: processed 32 file(s)
# Patient ID_df30d45c: processed 32 file(s)
# Patient ID_df4f833b: processed 108 file(s)
# Patient ID_df6e2c7e: processed 40 file(s)
# Patient ID_dfa39946: processed 166 file(s)
# Patient ID_dfd11f1c: processed 118 file(s)
# Patient ID_dff1fa85: processed 68 file(s)
# Patient ID_e01005ce: processed 34 file(s)
# Patient ID_e017154b: processed 202 file(s)
# Patient ID_e054ecc8: processed 32 file(s)
# Patient ID_e05ab819: processed 31 file(s)
# Patient ID_e070edfa: processed 38 file(s)
# Patient ID_e08906bc: processed 36 file(s)
# Patient ID_e08b6350: processed 68 file(s)
# Patient ID_e095d626: processed 28 file(s)
# Patient ID_e0b4a2a2: processed 42 file(s)
# Patient ID_e0fd4285: processed 41 file(s)
# Patient ID_e10d19e2: processed 36 file(s)
# Patient ID_e1be8ce4: processed 100 file(s)
# Patient ID_e1f3e80e: processed 30 file(s)
# Patient ID_e228ec60: processed 29 file(s)
# Patient ID_e23364fa: processed 38 file(s)
# Patient ID_e2a5a300: processed 40 file(s)
# Patient ID_e2d4665c: processed 46 file(s)
# Patient ID_e34ca49d: processed 38 file(s)
# Patient ID_e35cedea: processed 44 file(s)
# Patient ID_e393f193: processed 30 file(s)
# Patient ID_e39c9932: processed 67 file(s)
# Patient ID_e3ba5cf7: processed 60 file(s)
# Patient ID_e4488e09: processed 192 file(s)
# Patient ID_e48463fa: processed 32 file(s)
# Patient ID_e4ffd781: processed 31 file(s)
# Patient ID_e566ef9b: processed 32 file(s)
# Patient ID_e5dc2ecf: processed 43 file(s)
# Patient ID_e60060d0: processed 42 file(s)
# Patient ID_e6722bcf: processed 111 file(s)
# Patient ID_e6932bed: processed 44 file(s)
# Patient ID_e715684e: processed 40 file(s)
# Patient ID_e731a1c8: processed 71 file(s)
# Patient ID_e79c618e: processed 36 file(s)
# Patient ID_e7a14bf5: processed 35 file(s)
# Patient ID_e7e34e9e: processed 31 file(s)
# Patient ID_e7fb07db: processed 36 file(s)
# Patient ID_e83511c4: processed 76 file(s)
# Patient ID_e867fe7a: processed 28 file(s)
# Patient ID_e874b8c9: processed 220 file(s)
# Patient ID_e8815d89: processed 32 file(s)
# Patient ID_e8c8d283: processed 32 file(s)
# Patient ID_e8fe82da: processed 132 file(s)
# Patient ID_e9b05f1c: processed 36 file(s)
# Patient ID_ea1f8876: processed 33 file(s)
# Patient ID_eaf65d0e: processed 108 file(s)
# Patient ID_eb383c7a: processed 28 file(s)
# Patient ID_eb7ce28a: processed 32 file(s)
# Patient ID_eba9f1a7: processed 44 file(s)
# Patient ID_ecd7e320: processed 40 file(s)
# Patient ID_ecd8d7ec: processed 32 file(s)
# Patient ID_ed056f84: processed 52 file(s)
# Patient ID_ed7be44c: processed 36 file(s)
# Patient ID_edc1a834: processed 32 file(s)
# Patient ID_ee150dc0: processed 30 file(s)
# Patient ID_ee20e4ba: processed 34 file(s)
# Patient ID_ee7ba95f: processed 76 file(s)
# Patient ID_eeb4ec36: processed 30 file(s)
# Patient ID_eed25553: processed 124 file(s)
# Patient ID_eedfa085: processed 40 file(s)
# Patient ID_eee876b5: processed 40 file(s)
# Patient ID_eef431b9: processed 30 file(s)
# Patient ID_ef7dc5c1: processed 34 file(s)
# Patient ID_f038ceda: processed 74 file(s)
# Patient ID_f07588df: processed 148 file(s)
# Patient ID_f0c08bc4: processed 33 file(s)
# Patient ID_f0d7fb4f: processed 84 file(s)
# Patient ID_f0f75643: processed 32 file(s)
# Patient ID_f1079266: processed 37 file(s)
# Patient ID_f1635079: processed 37 file(s)
# Patient ID_f1e247fb: processed 36 file(s)
# Patient ID_f204d8f9: processed 42 file(s)
# Patient ID_f27d46d1: processed 32 file(s)
# Patient ID_f2939e11: processed 40 file(s)
# Patient ID_f2abe525: processed 40 file(s)
# Patient ID_f2e6e5b4: processed 32 file(s)
# Patient ID_f365aa20: processed 36 file(s)
# Patient ID_f39a4d5d: processed 32 file(s)
# Patient ID_f3ca99fb: processed 28 file(s)
# Patient ID_f3e41f0c: processed 36 file(s)
# Patient ID_f4212d9e: processed 35 file(s)
# Patient ID_f498df47: processed 40 file(s)
# Patient ID_f4bf153b: processed 34 file(s)
# Patient ID_f500d8aa: processed 28 file(s)
# Patient ID_f500f072: processed 104 file(s)
# Patient ID_f54e57db: processed 24 file(s)
# Patient ID_f55ca0f3: processed 30 file(s)
# Patient ID_f55e66d5: processed 28 file(s)
# Patient ID_f5643190: processed 288 file(s)
# Patient ID_f59ee23e: processed 33 file(s)
# Patient ID_f5e85730: processed 32 file(s)
# Patient ID_f6001093: processed 38 file(s)
# Patient ID_f62da880: processed 32 file(s)
# Patient ID_f64723ab: processed 32 file(s)
# Patient ID_f651f957: processed 70 file(s)
# Patient ID_f742a58e: processed 64 file(s)
# Patient ID_f772d97c: processed 41 file(s)
# Patient ID_f77f2422: processed 80 file(s)
# Patient ID_f7995ea2: processed 56 file(s)
# Patient ID_f7c5b11f: processed 64 file(s)
# Patient ID_f7d77307: processed 30 file(s)
# Patient ID_f8453085: processed 40 file(s)
# Patient ID_f87433b7: processed 34 file(s)
# Patient ID_f8da191e: processed 32 file(s)
# Patient ID_f8e8e3b1: processed 45 file(s)
# Patient ID_f928b8d1: processed 32 file(s)
# Patient ID_f995726a: processed 48 file(s)
# Patient ID_f9f79ffe: processed 33 file(s)
# Patient ID_fb2f0041: processed 30 file(s)
# Patient ID_fbc74834: processed 32 file(s)
# Patient ID_fc504748: processed 40 file(s)
# Patient ID_fc69f9ce: processed 32 file(s)
# Patient ID_fc9442d1: processed 160 file(s)
# Patient ID_fcbf2006: processed 32 file(s)
# Patient ID_fd8ab0a0: processed 108 file(s)
# Patient ID_fe709f1f: processed 32 file(s)
# Patient ID_feb83fb3: processed 187 file(s)
# Patient ID_fec357c9: processed 32 file(s)
# Patient ID_fec504bc: processed 32 file(s)
# Patient ID_fed25cd9: processed 66 file(s)
# Patient ID_ff2c88f6: processed 40 file(s)
# Patient ID_ff40fe30: processed 32 file(s)
# Patient ID_ff5e6c57: processed 38 file(s)
# Patient ID_ffc99fd6: processed 92 file(s)
# Patient ID_ffd91f66: processed 32 file(s)
# Patient patient_images_500_1000: no new DICOMs to process

# %%
import os
import re
import pydicom
import numpy as np
from PIL import Image

# Three head-CT HU-windows
WINDOWS = {
    'brain':    {'center':  40,  'width':   80},
    'subdural': {'center':  80,  'width':  200},
    'bone':     {'center': 500,  'width': 2000},
}

def window_image(hu_array: np.ndarray, center: float, width: float) -> np.ndarray:
    """
    Apply a window to a HU array:
      - Clips to [center - width/2, center + width/2]
      - Linearly scales to [0,255]
    Returns uint8 image.
    """
    low  = center - width/2
    high = center + width/2
    clipped = np.clip(hu_array, low, high)
    scaled  = (clipped - low) / (high - low) * 255.0
    return scaled.astype(np.uint8)

def apply_windows_to_sorted_dataset(work_dir: str):
    """
    For each patient folder under work_dir, finds files named like '0001_*.dcm',
    converts to HU, applies each window, and writes out PNGs named
    '0001_base_brain.png', etc.
    """
    for pid in sorted(os.listdir(work_dir)):
        pid_folder = os.path.join(work_dir, pid)
        if not os.path.isdir(pid_folder):
            continue

        # find only the prefixed DICOMs
        dcm_files = sorted(f for f in os.listdir(pid_folder)
                           if re.match(r'^\d{4}_.*\.dcm$', f, flags=re.IGNORECASE))

        if not dcm_files:
            print(f"[{pid}] no sorted DICOMs found, skipping")
            continue

        for fname in dcm_files:
            dcm_path = os.path.join(pid_folder, fname)
            try:
                ds = pydicom.dcmread(dcm_path)
                arr = ds.pixel_array.astype(np.float32)
                intercept = getattr(ds, 'RescaleIntercept', 0.0)
                slope     = getattr(ds, 'RescaleSlope',     1.0)
                hu = arr * slope + intercept

                base, _ = os.path.splitext(fname)
                for win_name, win in WINDOWS.items():
                    img = window_image(hu, win['center'], win['width'])
                    out_name = f"{base}_{win_name}.png"
                    out_path = os.path.join(pid_folder, out_name)
                    if not os.path.exists(out_path):
                        Image.fromarray(img).save(out_path)

            except Exception as e:
                print(f"Failed on {dcm_path}: {e}")

        print(f"[{pid}] windows applied to {len(dcm_files)} slices")


WORK_DIR = './patient_images_0_1000' 
apply_windows_to_sorted_dataset(WORK_DIR)
# Out:
# [ID_00526c11] windows applied to 84 slices
# [ID_00859e11] windows applied to 32 slices
# [ID_0086733c] windows applied to 28 slices
# [ID_00e30393] windows applied to 31 slices
# [ID_013cf2a2] windows applied to 44 slices
# [ID_02bdea77] windows applied to 30 slices
# [ID_03e3ed6d] windows applied to 45 slices
# [ID_0402b53e] windows applied to 30 slices
# [ID_046b584b] windows applied to 141 slices
# [ID_047b307a] windows applied to 44 slices
# [ID_048d5624] windows applied to 34 slices
# [ID_04a7b221] windows applied to 33 slices
# [ID_04fcd3da] windows applied to 178 slices
# [ID_0515ef2f] windows applied to 28 slices
# [ID_0531c34e] windows applied to 34 slices
# [ID_05bb1f88] windows applied to 32 slices
# [ID_05d3ffff] windows applied to 42 slices
# [ID_05fa237b] windows applied to 65 slices
# [ID_06185aa5] windows applied to 34 slices
# [ID_06b045bf] windows applied to 247 slices
# [ID_06c7d632] windows applied to 28 slices
# [ID_06edbec1] windows applied to 34 slices
# [ID_0762da12] windows applied to 40 slices
# [ID_07741131] windows applied to 33 slices
# [ID_0781672a] windows applied to 30 slices
# [ID_083f644d] windows applied to 46 slices
# [ID_08a89e8e] windows applied to 32 slices
# [ID_090f8b79] windows applied to 32 slices
# [ID_09409fc7] windows applied to 36 slices
# [ID_09422b4a] windows applied to 80 slices
# [ID_095c522a] windows applied to 64 slices
# [ID_09681778] windows applied to 29 slices
# [ID_09bf6329] windows applied to 116 slices
# [ID_09e88cd7] windows applied to 33 slices
# [ID_0a01a6c4] windows applied to 32 slices
# [ID_0a0ef792] windows applied to 44 slices
# [ID_0a125878] windows applied to 32 slices
# [ID_0a360fb1] windows applied to 48 slices
# [ID_0ad31a65] windows applied to 36 slices
# [ID_0b902b36] windows applied to 36 slices
# [ID_0baadb05] windows applied to 40 slices
# [ID_0be3fa40] windows applied to 32 slices
# [ID_0c3208e4] windows applied to 30 slices
# [ID_0cd1512c] windows applied to 37 slices
# [ID_0cddb2a2] windows applied to 30 slices
# [ID_0ce7ddbc] windows applied to 132 slices
# [ID_0d1c1633] windows applied to 40 slices
# [ID_0d58c8e1] windows applied to 36 slices
# [ID_0e386dca] windows applied to 32 slices
# [ID_0e780605] windows applied to 33 slices
# [ID_0e91f449] windows applied to 36 slices
# [ID_0f2a00e5] windows applied to 59 slices
# [ID_0f38cdb1] windows applied to 32 slices
# [ID_0f561411] windows applied to 69 slices
# [ID_0fbd7809] windows applied to 52 slices
# [ID_0ff437c4] windows applied to 100 slices
# [ID_102767c7] windows applied to 33 slices
# [ID_10398493] windows applied to 32 slices
# [ID_106d2f99] windows applied to 32 slices
# [ID_10b9a991] windows applied to 69 slices
# [ID_10beb45f] windows applied to 28 slices
# [ID_112f4511] windows applied to 102 slices
# [ID_114513b0] windows applied to 39 slices
# [ID_116c8896] windows applied to 46 slices
# [ID_12874243] windows applied to 36 slices
# [ID_1290e471] windows applied to 34 slices
# [ID_12bd4f33] windows applied to 40 slices
# [ID_134f661b] windows applied to 36 slices
# [ID_13d85b1f] windows applied to 36 slices
# [ID_141acd90] windows applied to 32 slices
# [ID_14353770] windows applied to 44 slices
# [ID_1439ac67] windows applied to 33 slices
# [ID_1495daf7] windows applied to 70 slices
# [ID_1534f4c8] windows applied to 35 slices
# [ID_153e43bf] windows applied to 136 slices
# [ID_1596b352] windows applied to 28 slices
# [ID_16332433] windows applied to 31 slices
# [ID_16a23d6a] windows applied to 36 slices
# [ID_16f719a5] windows applied to 38 slices
# [ID_17027b61] windows applied to 32 slices
# [ID_18747540] windows applied to 34 slices
# [ID_189d891f] windows applied to 35 slices
# [ID_18a14c7e] windows applied to 37 slices
# [ID_18b1bd8d] windows applied to 30 slices
# [ID_191f3e4e] windows applied to 35 slices
# [ID_19248abb] windows applied to 36 slices
# [ID_193acffb] windows applied to 28 slices
# [ID_194db451] windows applied to 38 slices
# [ID_1974581d] windows applied to 28 slices
# [ID_19edd875] windows applied to 88 slices
# [ID_1a23c93a] windows applied to 32 slices
# [ID_1a6a5070] windows applied to 24 slices
# [ID_1a6d2d97] windows applied to 32 slices
# [ID_1aae01db] windows applied to 40 slices
# [ID_1afd9477] windows applied to 116 slices
# [ID_1b402138] windows applied to 32 slices
# [ID_1b5b14ad] windows applied to 36 slices
# [ID_1c312e63] windows applied to 34 slices
# [ID_1c8bddb0] windows applied to 40 slices
# [ID_1c9c37ad] windows applied to 28 slices
# [ID_1cbe2853] windows applied to 32 slices
# [ID_1cc5c8d4] windows applied to 44 slices
# [ID_1dbe2d50] windows applied to 39 slices
# [ID_1e006bbc] windows applied to 32 slices
# [ID_1e10ccf2] windows applied to 31 slices
# [ID_1e433917] windows applied to 35 slices
# [ID_1e74903a] windows applied to 112 slices
# [ID_1f15256c] windows applied to 42 slices
# [ID_1f806a1a] windows applied to 36 slices
# [ID_1f8667af] windows applied to 68 slices
# [ID_1f8fa544] windows applied to 36 slices
# [ID_1fa0e188] windows applied to 36 slices
# [ID_2003f57e] windows applied to 31 slices
# [ID_2086c7f3] windows applied to 173 slices
# [ID_20a06aa9] windows applied to 30 slices
# [ID_20c2b489] windows applied to 31 slices
# [ID_2160b72b] windows applied to 45 slices
# [ID_21ae9427] windows applied to 36 slices
# [ID_21e3372e] windows applied to 28 slices
# [ID_22389cfd] windows applied to 32 slices
# [ID_22427ffe] windows applied to 32 slices
# [ID_22686923] windows applied to 40 slices
# [ID_229f6a42] windows applied to 40 slices
# [ID_22c909b4] windows applied to 32 slices
# [ID_2319d650] windows applied to 142 slices
# [ID_2349a958] windows applied to 36 slices
# [ID_234cf552] windows applied to 44 slices
# [ID_2378f0b7] windows applied to 64 slices
# [ID_23fe5436] windows applied to 28 slices
# [ID_24645857] windows applied to 34 slices
# [ID_24965b9e] windows applied to 33 slices
# [ID_24df80e7] windows applied to 384 slices
# [ID_24f9bfc5] windows applied to 40 slices
# [ID_2565057f] windows applied to 32 slices
# [ID_25ed6070] windows applied to 44 slices
# [ID_275616cd] windows applied to 35 slices
# [ID_27a5a7f2] windows applied to 37 slices
# [ID_27afd104] windows applied to 36 slices
# [ID_27b1f19b] windows applied to 32 slices
# [ID_27b6ff99] windows applied to 32 slices
# [ID_27ddc408] windows applied to 59 slices
# [ID_2802e154] windows applied to 30 slices
# [ID_28039788] windows applied to 35 slices
# [ID_28622235] windows applied to 64 slices
# [ID_28701613] windows applied to 44 slices
# [ID_28733cfd] windows applied to 32 slices
# [ID_288e230e] windows applied to 51 slices
# [ID_29137d4e] windows applied to 34 slices
# [ID_29222f4e] windows applied to 64 slices
# [ID_2922ed6e] windows applied to 70 slices
# [ID_29233b7b] windows applied to 80 slices
# [ID_292c63fc] windows applied to 34 slices
# [ID_29528b54] windows applied to 35 slices
# [ID_2993fb73] windows applied to 102 slices
# [ID_29d2772a] windows applied to 32 slices
# [ID_2aa56078] windows applied to 30 slices
# [ID_2b35cfb8] windows applied to 52 slices
# [ID_2b714f1a] windows applied to 40 slices
# [ID_2b75e193] windows applied to 103 slices
# [ID_2b8741c5] windows applied to 122 slices
# [ID_2b8838d6] windows applied to 36 slices
# [ID_2bc99005] windows applied to 32 slices
# [ID_2bf60fbd] windows applied to 48 slices
# [ID_2cc29d59] windows applied to 30 slices
# [ID_2cfc710f] windows applied to 34 slices
# [ID_2d44d017] windows applied to 245 slices
# [ID_2d509aa7] windows applied to 74 slices
# [ID_2df3deb9] windows applied to 33 slices
# [ID_2e55ccb9] windows applied to 106 slices
# [ID_2e9eb3f8] windows applied to 42 slices
# [ID_2ea889e3] windows applied to 178 slices
# [ID_2ecaabfe] windows applied to 264 slices
# [ID_2efbb26d] windows applied to 88 slices
# [ID_2f02b88c] windows applied to 34 slices
# [ID_2f08ea2c] windows applied to 32 slices
# [ID_2f527103] windows applied to 40 slices
# [ID_300a120b] windows applied to 29 slices
# [ID_30ca28d8] windows applied to 60 slices
# [ID_30d19531] windows applied to 32 slices
# [ID_31015256] windows applied to 32 slices
# [ID_3110c9de] windows applied to 30 slices
# [ID_31652e46] windows applied to 256 slices
# [ID_31d1554f] windows applied to 64 slices
# [ID_320a1703] windows applied to 36 slices
# [ID_32150121] windows applied to 72 slices
# [ID_325f8c88] windows applied to 189 slices
# [ID_32c07778] windows applied to 28 slices
# [ID_32f4a8ed] windows applied to 40 slices
# [ID_331a0a71] windows applied to 32 slices
# [ID_339d9651] windows applied to 34 slices
# [ID_33a6fa45] windows applied to 40 slices
# [ID_33c23df3] windows applied to 33 slices
# [ID_33d65356] windows applied to 36 slices
# [ID_34375431] windows applied to 40 slices
# [ID_34480fbb] windows applied to 28 slices
# [ID_345c66cd] windows applied to 36 slices
# [ID_34ac4fd9] windows applied to 28 slices
# [ID_34adcc3e] windows applied to 68 slices
# [ID_34be79b0] windows applied to 36 slices
# [ID_3557cc57] windows applied to 32 slices
# [ID_35a154ec] windows applied to 32 slices
# [ID_35cacafa] windows applied to 32 slices
# [ID_361eb5ee] windows applied to 44 slices
# [ID_3661d884] windows applied to 33 slices
# [ID_36c4424f] windows applied to 32 slices
# [ID_36e5050e] windows applied to 40 slices
# [ID_3750087a] windows applied to 132 slices
# [ID_37804bff] windows applied to 48 slices
# [ID_380f3b4a] windows applied to 35 slices
# [ID_38797203] windows applied to 35 slices
# [ID_38f8dd68] windows applied to 36 slices
# [ID_3956b469] windows applied to 170 slices
# [ID_3956f565] windows applied to 40 slices
# [ID_397b1ec6] windows applied to 32 slices
# [ID_39c814dd] windows applied to 169 slices
# [ID_3a3c2570] windows applied to 36 slices
# [ID_3a6b2a4a] windows applied to 40 slices
# [ID_3abd9afd] windows applied to 32 slices
# [ID_3b323613] windows applied to 139 slices
# [ID_3bbf73cb] windows applied to 40 slices
# [ID_3bc85ab1] windows applied to 37 slices
# [ID_3be63ca2] windows applied to 66 slices
# [ID_3c10f9dd] windows applied to 32 slices
# [ID_3c39aa25] windows applied to 34 slices
# [ID_3c4bab8c] windows applied to 40 slices
# [ID_3c7d692a] windows applied to 32 slices
# [ID_3d041e67] windows applied to 32 slices
# [ID_3d19ab45] windows applied to 78 slices
# [ID_3d6d5c25] windows applied to 34 slices
# [ID_3d9d3a41] windows applied to 36 slices
# [ID_3e0ecc51] windows applied to 32 slices
# [ID_3e11ee12] windows applied to 63 slices
# [ID_3eaaa176] windows applied to 66 slices
# [ID_3f0af787] windows applied to 38 slices
# [ID_3f2366c7] windows applied to 54 slices
# [ID_3f244bf8] windows applied to 83 slices
# [ID_3ff3f64f] windows applied to 32 slices
# [ID_402555db] windows applied to 116 slices
# [ID_40500791] windows applied to 36 slices
# [ID_407b437c] windows applied to 88 slices
# [ID_408e5a45] windows applied to 44 slices
# [ID_413a205e] windows applied to 64 slices
# [ID_41496e62] windows applied to 76 slices
# [ID_41b580cc] windows applied to 64 slices
# [ID_41fbad2a] windows applied to 32 slices
# [ID_421687f2] windows applied to 44 slices
# [ID_425a04e2] windows applied to 36 slices
# [ID_42aaa797] windows applied to 32 slices
# [ID_42ec8de3] windows applied to 44 slices
# [ID_434057f7] windows applied to 32 slices
# [ID_434a9402] windows applied to 32 slices
# [ID_43a937d5] windows applied to 40 slices
# [ID_43cb6c19] windows applied to 28 slices
# [ID_445f82bd] windows applied to 68 slices
# [ID_44aa00c6] windows applied to 40 slices
# [ID_4572a50a] windows applied to 32 slices
# [ID_457fb04c] windows applied to 40 slices
# [ID_45ab53bc] windows applied to 44 slices
# [ID_462cddb3] windows applied to 144 slices
# [ID_4631069b] windows applied to 32 slices
# [ID_464e2d16] windows applied to 53 slices
# [ID_468db19c] windows applied to 31 slices
# [ID_46f96b4b] windows applied to 28 slices
# [ID_474cc974] windows applied to 36 slices
# [ID_4760870c] windows applied to 32 slices
# [ID_4820fde0] windows applied to 35 slices
# [ID_484df4eb] windows applied to 32 slices
# [ID_488a1f4c] windows applied to 32 slices
# [ID_4892efc1] windows applied to 36 slices
# [ID_48b141a3] windows applied to 35 slices
# [ID_48ea9ffe] windows applied to 28 slices
# [ID_491ecfc5] windows applied to 35 slices
# [ID_4941c875] windows applied to 33 slices
# [ID_49b72d08] windows applied to 65 slices
# [ID_4a6046d7] windows applied to 32 slices
# [ID_4a89eaec] windows applied to 64 slices
# [ID_4a8b7f44] windows applied to 40 slices
# [ID_4ab8a38c] windows applied to 37 slices
# [ID_4b0046ad] windows applied to 68 slices
# [ID_4bc7e34f] windows applied to 69 slices
# [ID_4bcc8462] windows applied to 30 slices
# [ID_4bdb4ca4] windows applied to 37 slices
# [ID_4c5203e4] windows applied to 40 slices
# [ID_4d117ca6] windows applied to 35 slices
# [ID_4d50a305] windows applied to 34 slices
# [ID_4d990362] windows applied to 97 slices
# [ID_4e017d09] windows applied to 32 slices
# [ID_4e072077] windows applied to 35 slices
# [ID_4e50b56c] windows applied to 41 slices
# [ID_4e8a1468] windows applied to 76 slices
# [ID_4ecb1803] windows applied to 32 slices
# [ID_4ed55706] windows applied to 32 slices
# [ID_4ee06dce] windows applied to 31 slices
# [ID_4ef5d2c2] windows applied to 37 slices
# [ID_4f1388ee] windows applied to 157 slices
# [ID_4f2ef6bd] windows applied to 28 slices
# [ID_4f69cfc4] windows applied to 71 slices
# [ID_4f87ed82] windows applied to 280 slices
# [ID_4fa6c826] windows applied to 36 slices
# [ID_4fdc5779] windows applied to 71 slices
# [ID_4fe0762c] windows applied to 34 slices
# [ID_500d4c17] windows applied to 60 slices
# [ID_5078baa1] windows applied to 24 slices
# [ID_50db970d] windows applied to 32 slices
# [ID_5117f9bf] windows applied to 349 slices
# [ID_514485c6] windows applied to 36 slices
# [ID_51d12de3] windows applied to 48 slices
# [ID_5214af9f] windows applied to 100 slices
# [ID_5250540f] windows applied to 40 slices
# [ID_52f5f4c0] windows applied to 38 slices
# [ID_532343e0] windows applied to 36 slices
# [ID_538abc9c] windows applied to 37 slices
# [ID_539b1ea8] windows applied to 40 slices
# [ID_53a56157] windows applied to 40 slices
# [ID_54523464] windows applied to 36 slices
# [ID_54ff9969] windows applied to 43 slices
# [ID_55179c9f] windows applied to 36 slices
# [ID_551fb566] windows applied to 40 slices
# [ID_556bbb81] windows applied to 32 slices
# [ID_55f41512] windows applied to 74 slices
# [ID_55fe5ea0] windows applied to 68 slices
# [ID_562453fd] windows applied to 40 slices
# [ID_5670297a] windows applied to 29 slices
# [ID_567a54f7] windows applied to 34 slices
# [ID_56b481a5] windows applied to 36 slices
# [ID_57374966] windows applied to 30 slices
# [ID_574ff0ed] windows applied to 40 slices
# [ID_57abb053] windows applied to 77 slices
# [ID_57d2ec05] windows applied to 38 slices
# [ID_57e2d878] windows applied to 32 slices
# [ID_580dc795] windows applied to 40 slices
# [ID_588b05d0] windows applied to 46 slices
# [ID_58c4b9c9] windows applied to 40 slices
# [ID_590781ec] windows applied to 32 slices
# [ID_59293228] windows applied to 33 slices
# [ID_59449a15] windows applied to 40 slices
# [ID_5962fb9d] windows applied to 32 slices
# [ID_596ab7ed] windows applied to 38 slices
# [ID_599b7c86] windows applied to 40 slices
# [ID_59cfd681] windows applied to 40 slices
# [ID_59fc3412] windows applied to 291 slices
# [ID_5a2f9b4e] windows applied to 33 slices
# [ID_5a5c48f2] windows applied to 28 slices
# [ID_5ac1d167] windows applied to 34 slices
# [ID_5aed7871] windows applied to 104 slices
# [ID_5b37c199] windows applied to 28 slices
# [ID_5b557029] windows applied to 66 slices
# [ID_5babfee6] windows applied to 33 slices
# [ID_5cddd1a2] windows applied to 28 slices
# [ID_5d225217] windows applied to 38 slices
# [ID_5e0abe00] windows applied to 32 slices
# [ID_5e0cb0fa] windows applied to 38 slices
# [ID_5e4a8dc5] windows applied to 36 slices
# [ID_5ebb934e] windows applied to 32 slices
# [ID_5ecd8190] windows applied to 36 slices
# [ID_5ee71b4f] windows applied to 36 slices
# [ID_5f10bb06] windows applied to 40 slices
# [ID_5f292ef8] windows applied to 40 slices
# [ID_5fab93e1] windows applied to 40 slices
# [ID_5fad6382] windows applied to 40 slices
# [ID_5fc24d8d] windows applied to 32 slices
# [ID_605b0387] windows applied to 34 slices
# [ID_6074f71f] windows applied to 28 slices
# [ID_608fe899] windows applied to 64 slices
# [ID_60aa8388] windows applied to 28 slices
# [ID_60dadd86] windows applied to 44 slices
# [ID_60de2d45] windows applied to 56 slices
# [ID_61230c87] windows applied to 40 slices
# [ID_6172a307] windows applied to 40 slices
# [ID_621617b5] windows applied to 44 slices
# [ID_621b02fb] windows applied to 68 slices
# [ID_626bbe7e] windows applied to 62 slices
# [ID_631bb202] windows applied to 64 slices
# [ID_6338c4f1] windows applied to 80 slices
# [ID_63862d24] windows applied to 60 slices
# [ID_63fc0170] windows applied to 40 slices
# [ID_6401f47a] windows applied to 30 slices
# [ID_64135901] windows applied to 36 slices
# [ID_642e553b] windows applied to 67 slices
# [ID_643b4943] windows applied to 38 slices
# [ID_6480f55c] windows applied to 36 slices
# [ID_64bedb53] windows applied to 32 slices
# [ID_65068cc1] windows applied to 41 slices
# [ID_65570143] windows applied to 28 slices
# [ID_658089c2] windows applied to 36 slices
# [ID_65ce3fbf] windows applied to 40 slices
# [ID_65f05a7f] windows applied to 32 slices
# [ID_66a789d2] windows applied to 35 slices
# [ID_66de94cd] windows applied to 124 slices
# [ID_6729fc03] windows applied to 48 slices
# [ID_672d9eeb] windows applied to 40 slices
# [ID_673d2622] windows applied to 40 slices
# [ID_677f38f6] windows applied to 36 slices
# [ID_67967387] windows applied to 92 slices
# [ID_679a9829] windows applied to 32 slices
# [ID_67e3dd2d] windows applied to 67 slices
# [ID_6832d244] windows applied to 40 slices
# [ID_6870bde2] windows applied to 80 slices
# [ID_6920db8a] windows applied to 44 slices
# [ID_693be4b0] windows applied to 36 slices
# [ID_694877bd] windows applied to 41 slices
# [ID_69dc1705] windows applied to 32 slices
# [ID_6a0e73c3] windows applied to 32 slices
# [ID_6a1529ae] windows applied to 32 slices
# [ID_6a47d33a] windows applied to 156 slices
# [ID_6a656c8c] windows applied to 41 slices
# [ID_6a954d3e] windows applied to 36 slices
# [ID_6ae0c0e4] windows applied to 32 slices
# [ID_6b72349b] windows applied to 34 slices
# [ID_6b81bd74] windows applied to 64 slices
# [ID_6b9a6754] windows applied to 28 slices
# [ID_6bd8a97b] windows applied to 28 slices
# [ID_6c1e51d3] windows applied to 36 slices
# [ID_6c200fb9] windows applied to 44 slices
# [ID_6c4eb5be] windows applied to 32 slices
# [ID_6c95cb7d] windows applied to 69 slices
# [ID_6d156aa6] windows applied to 73 slices
# [ID_6d909bb6] windows applied to 28 slices
# [ID_6dc616fa] windows applied to 30 slices
# [ID_6dd8a1f8] windows applied to 72 slices
# [ID_6e148bb6] windows applied to 28 slices
# [ID_6e16ad64] windows applied to 36 slices
# [ID_6e2e88da] windows applied to 35 slices
# [ID_6e5b4966] windows applied to 36 slices
# [ID_6e6b5160] windows applied to 74 slices
# [ID_6e825319] windows applied to 101 slices
# [ID_6edb3e25] windows applied to 38 slices
# [ID_6ee3c214] windows applied to 64 slices
# [ID_6fd208b9] windows applied to 72 slices
# [ID_7024a509] windows applied to 36 slices
# [ID_7024db3a] windows applied to 32 slices
# [ID_71effc3d] windows applied to 32 slices
# [ID_7207fa95] windows applied to 34 slices
# [ID_7247a27a] windows applied to 40 slices
# [ID_72ba98d4] windows applied to 31 slices
# [ID_72f3abed] windows applied to 32 slices
# [ID_7427a380] windows applied to 40 slices
# [ID_747b2d22] windows applied to 41 slices
# [ID_74a1b5be] windows applied to 39 slices
# [ID_74e102b8] windows applied to 104 slices
# [ID_7564de50] windows applied to 28 slices
# [ID_75656cb3] windows applied to 32 slices
# [ID_75714feb] windows applied to 40 slices
# [ID_761ba61f] windows applied to 38 slices
# [ID_769c4f5a] windows applied to 40 slices
# [ID_76a9cfba] windows applied to 36 slices
# [ID_771166b1] windows applied to 40 slices
# [ID_7739fdb9] windows applied to 36 slices
# [ID_778967e4] windows applied to 37 slices
# [ID_782108c8] windows applied to 40 slices
# [ID_786336c9] windows applied to 36 slices
# [ID_795755b3] windows applied to 35 slices
# [ID_79669711] windows applied to 33 slices
# [ID_7997c82e] windows applied to 32 slices
# [ID_79c0838b] windows applied to 199 slices
# [ID_79c52943] windows applied to 32 slices
# [ID_79d9bab1] windows applied to 31 slices
# [ID_79f5d8f7] windows applied to 35 slices
# [ID_7a15e805] windows applied to 33 slices
# [ID_7a83bc13] windows applied to 28 slices
# [ID_7a931ed4] windows applied to 32 slices
# [ID_7a9e8209] windows applied to 64 slices
# [ID_7adf3447] windows applied to 36 slices
# [ID_7af8f437] windows applied to 37 slices
# [ID_7b0527a1] windows applied to 28 slices
# [ID_7b060526] windows applied to 32 slices
# [ID_7b26602e] windows applied to 28 slices
# [ID_7b3aaf8b] windows applied to 34 slices
# [ID_7b4d1d09] windows applied to 80 slices
# [ID_7b9a8838] windows applied to 73 slices
# [ID_7ba59d14] windows applied to 30 slices
# [ID_7bcf0282] windows applied to 35 slices
# [ID_7c5d364a] windows applied to 32 slices
# [ID_7ca17546] windows applied to 60 slices
# [ID_7d0370ac] windows applied to 39 slices
# [ID_7d05d937] windows applied to 33 slices
# [ID_7d3d32cf] windows applied to 28 slices
# [ID_7d5b36f9] windows applied to 34 slices
# [ID_7d75d290] windows applied to 40 slices
# [ID_7d89c44f] windows applied to 40 slices
# [ID_7df7ad0a] windows applied to 48 slices
# [ID_7e12098c] windows applied to 30 slices
# [ID_7e97e16e] windows applied to 32 slices
# [ID_7eab9495] windows applied to 34 slices
# [ID_7ed4a54f] windows applied to 42 slices
# [ID_7f6ee367] windows applied to 32 slices
# [ID_802aede8] windows applied to 46 slices
# [ID_8067d3e8] windows applied to 30 slices
# [ID_806a8589] windows applied to 32 slices
# [ID_8074f54e] windows applied to 33 slices
# [ID_80ef001a] windows applied to 44 slices
# [ID_81031dfb] windows applied to 60 slices
# [ID_810c8c03] windows applied to 32 slices
# [ID_814929cb] windows applied to 46 slices
# [ID_819de77c] windows applied to 30 slices
# [ID_8227d646] windows applied to 31 slices
# [ID_825cf2b2] windows applied to 38 slices
# [ID_829131ae] windows applied to 30 slices
# [ID_82b32d95] windows applied to 32 slices
# [ID_8313c071] windows applied to 32 slices
# [ID_836e19d8] windows applied to 29 slices
# [ID_83e2fff4] windows applied to 72 slices
# [ID_83e6bdc7] windows applied to 72 slices
# [ID_845aa72d] windows applied to 64 slices
# [ID_8492cc67] windows applied to 60 slices
# [ID_84cb27c8] windows applied to 34 slices
# [ID_84e345eb] windows applied to 28 slices
# [ID_852ffdec] windows applied to 36 slices
# [ID_85377393] windows applied to 38 slices
# [ID_86302070] windows applied to 32 slices
# [ID_86467a1c] windows applied to 35 slices
# [ID_864a58c9] windows applied to 40 slices
# [ID_8676cf8c] windows applied to 36 slices
# [ID_8776abea] windows applied to 30 slices
# [ID_87ef7072] windows applied to 44 slices
# [ID_8813490e] windows applied to 36 slices
# [ID_886ae126] windows applied to 42 slices
# [ID_8884e2dd] windows applied to 37 slices
# [ID_88cce19a] windows applied to 28 slices
# [ID_890089ea] windows applied to 36 slices
# [ID_89077814] windows applied to 32 slices
# [ID_891ec6ab] windows applied to 32 slices
# [ID_8931541c] windows applied to 64 slices
# [ID_894936f8] windows applied to 31 slices
# [ID_895a8563] windows applied to 36 slices
# [ID_8997e646] windows applied to 60 slices
# [ID_89bdcc3b] windows applied to 32 slices
# [ID_8a278e5d] windows applied to 39 slices
# [ID_8a7d528a] windows applied to 32 slices
# [ID_8a867c75] windows applied to 32 slices
# [ID_8aa97af1] windows applied to 32 slices
# [ID_8ae969ac] windows applied to 36 slices
# [ID_8b01f879] windows applied to 29 slices
# [ID_8b5fc4f6] windows applied to 32 slices
# [ID_8bca9b69] windows applied to 48 slices
# [ID_8bfe6c11] windows applied to 28 slices
# [ID_8c298617] windows applied to 32 slices
# [ID_8cc63298] windows applied to 75 slices
# [ID_8d05b932] windows applied to 28 slices
# [ID_8d2d5588] windows applied to 32 slices
# [ID_8d77a804] windows applied to 36 slices
# [ID_8df20993] windows applied to 34 slices
# [ID_8e9ba7a2] windows applied to 36 slices
# [ID_8f8089df] windows applied to 66 slices
# [ID_905513a4] windows applied to 40 slices
# [ID_907f00d7] windows applied to 32 slices
# [ID_9091a7ef] windows applied to 31 slices
# [ID_90fd6087] windows applied to 32 slices
# [ID_910167fb] windows applied to 32 slices
# [ID_9116e504] windows applied to 31 slices
# [ID_91571425] windows applied to 32 slices
# [ID_91c16731] windows applied to 36 slices
# [ID_925ffd44] windows applied to 42 slices
# [ID_92d6579c] windows applied to 32 slices
# [ID_9304492f] windows applied to 64 slices
# [ID_935fe8a4] windows applied to 66 slices
# [ID_9372b733] windows applied to 39 slices
# [ID_93806008] windows applied to 285 slices
# [ID_93aa636f] windows applied to 35 slices
# [ID_93b150d0] windows applied to 173 slices
# [ID_9402feb3] windows applied to 38 slices
# [ID_940311b9] windows applied to 36 slices
# [ID_9476f262] windows applied to 40 slices
# [ID_94a74adb] windows applied to 36 slices
# [ID_95218960] windows applied to 37 slices
# [ID_9524a2ec] windows applied to 40 slices
# [ID_9537cb46] windows applied to 28 slices
# [ID_954d81e2] windows applied to 40 slices
# [ID_9557fa78] windows applied to 170 slices
# [ID_95deae29] windows applied to 36 slices
# [ID_96462e69] windows applied to 60 slices
# [ID_9660b760] windows applied to 32 slices
# [ID_96954f6b] windows applied to 34 slices
# [ID_96f03221] windows applied to 44 slices
# [ID_9733e86c] windows applied to 36 slices
# [ID_975457ab] windows applied to 35 slices
# [ID_97759401] windows applied to 39 slices
# [ID_97b47cd1] windows applied to 28 slices
# [ID_9857543b] windows applied to 28 slices
# [ID_98bad0cd] windows applied to 33 slices
# [ID_98df6fc3] windows applied to 78 slices
# [ID_99a527c9] windows applied to 36 slices
# [ID_99f8e875] windows applied to 141 slices
# [ID_9a78df90] windows applied to 88 slices
# [ID_9a807ed6] windows applied to 46 slices
# [ID_9b2b3fd9] windows applied to 32 slices
# [ID_9b2ce254] windows applied to 32 slices
# [ID_9bc2a1ba] windows applied to 28 slices
# [ID_9c55299b] windows applied to 36 slices
# [ID_9c6cadfc] windows applied to 28 slices
# [ID_9c79fc67] windows applied to 32 slices
# [ID_9ca1fc80] windows applied to 173 slices
# [ID_9cad3699] windows applied to 36 slices
# [ID_9d4732f1] windows applied to 32 slices
# [ID_9d613cb8] windows applied to 34 slices
# [ID_9eac3f88] windows applied to 56 slices
# [ID_9ec34a28] windows applied to 30 slices
# [ID_9eee80a4] windows applied to 32 slices
# [ID_9f027843] windows applied to 140 slices
# [ID_a044b66d] windows applied to 34 slices
# [ID_a065f3ac] windows applied to 34 slices
# [ID_a06c4a6d] windows applied to 32 slices
# [ID_a08b5982] windows applied to 80 slices
# [ID_a0be6fee] windows applied to 68 slices
# [ID_a0be926e] windows applied to 33 slices
# [ID_a0f2086d] windows applied to 48 slices
# [ID_a0f9a12e] windows applied to 30 slices
# [ID_a102494b] windows applied to 37 slices
# [ID_a1041905] windows applied to 200 slices
# [ID_a11e58c7] windows applied to 38 slices
# [ID_a12018e7] windows applied to 40 slices
# [ID_a14b61eb] windows applied to 32 slices
# [ID_a2117aff] windows applied to 28 slices
# [ID_a213129a] windows applied to 32 slices
# [ID_a21ccaf5] windows applied to 33 slices
# [ID_a2255eeb] windows applied to 36 slices
# [ID_a23fe79b] windows applied to 53 slices
# [ID_a2d35161] windows applied to 32 slices
# [ID_a2f3512f] windows applied to 44 slices
# [ID_a2fe752d] windows applied to 40 slices
# [ID_a2ffd116] windows applied to 32 slices
# [ID_a30e75ba] windows applied to 35 slices
# [ID_a31d97a2] windows applied to 38 slices
# [ID_a329da04] windows applied to 32 slices
# [ID_a38c865a] windows applied to 34 slices
# [ID_a3b0db7b] windows applied to 32 slices
# [ID_a3bb4e75] windows applied to 52 slices
# [ID_a4061ddd] windows applied to 36 slices
# [ID_a40bbd27] windows applied to 32 slices
# [ID_a46a1fcc] windows applied to 36 slices
# [ID_a470073a] windows applied to 34 slices
# [ID_a4780b6d] windows applied to 39 slices
# [ID_a47978d2] windows applied to 28 slices
# [ID_a49a5efc] windows applied to 32 slices
# [ID_a4b7b95b] windows applied to 32 slices
# [ID_a55d4722] windows applied to 40 slices
# [ID_a58c61b9] windows applied to 32 slices
# [ID_a59ca853] windows applied to 38 slices
# [ID_a5f71e3b] windows applied to 32 slices
# [ID_a603c877] windows applied to 30 slices
# [ID_a6466fc7] windows applied to 38 slices
# [ID_a6584b14] windows applied to 39 slices
# [ID_a661a555] windows applied to 42 slices
# [ID_a7d9d319] windows applied to 41 slices
# [ID_a7eef85b] windows applied to 64 slices
# [ID_a88550b0] windows applied to 32 slices
# [ID_a8d0c74d] windows applied to 39 slices
# [ID_a90855a6] windows applied to 60 slices
# [ID_a959a93c] windows applied to 32 slices
# [ID_a95e2a3a] windows applied to 80 slices
# [ID_a9679497] windows applied to 158 slices
# [ID_a9a5da1d] windows applied to 32 slices
# [ID_aa1e0c49] windows applied to 44 slices
# [ID_aa68fe42] windows applied to 40 slices
# [ID_aaa193ed] windows applied to 40 slices
# [ID_ab18679d] windows applied to 32 slices
# [ID_ab374c63] windows applied to 24 slices
# [ID_ab7c2a08] windows applied to 30 slices
# [ID_ab86cd88] windows applied to 32 slices
# [ID_ac4691db] windows applied to 275 slices
# [ID_ac55443e] windows applied to 32 slices
# [ID_ac57e226] windows applied to 84 slices
# [ID_aca1438c] windows applied to 173 slices
# [ID_ad40b5f6] windows applied to 40 slices
# [ID_ad520e68] windows applied to 40 slices
# [ID_ad5cebfc] windows applied to 50 slices
# [ID_ad83af8d] windows applied to 35 slices
# [ID_ae6caaa0] windows applied to 75 slices
# [ID_ae8edb71] windows applied to 28 slices
# [ID_ae975af3] windows applied to 62 slices
# [ID_ae9d2b26] windows applied to 32 slices
# [ID_af1f6a8a] windows applied to 40 slices
# [ID_af628585] windows applied to 42 slices
# [ID_af65b09e] windows applied to 37 slices
# [ID_af787505] windows applied to 32 slices
# [ID_afbdc96e] windows applied to 30 slices
# [ID_afbf985e] windows applied to 48 slices
# [ID_afd8ebfe] windows applied to 300 slices
# [ID_b0ac33ab] windows applied to 36 slices
# [ID_b0d7d2c9] windows applied to 36 slices
# [ID_b1d5d5e8] windows applied to 32 slices
# [ID_b1e72399] windows applied to 72 slices
# [ID_b1ff5bc4] windows applied to 96 slices
# [ID_b2b40794] windows applied to 32 slices
# [ID_b2cd8791] windows applied to 130 slices
# [ID_b2f933fa] windows applied to 156 slices
# [ID_b31ea623] windows applied to 101 slices
# [ID_b372d83f] windows applied to 31 slices
# [ID_b393cba9] windows applied to 56 slices
# [ID_b3a354f2] windows applied to 28 slices
# [ID_b3a96be5] windows applied to 30 slices
# [ID_b47f4fe4] windows applied to 36 slices
# [ID_b4a5aa19] windows applied to 39 slices
# [ID_b4dc0fe8] windows applied to 71 slices
# [ID_b4dcc61a] windows applied to 44 slices
# [ID_b501522f] windows applied to 32 slices
# [ID_b54ed8ef] windows applied to 28 slices
# [ID_b59d1617] windows applied to 32 slices
# [ID_b5e48ddb] windows applied to 34 slices
# [ID_b5f2914a] windows applied to 34 slices
# [ID_b667aeee] windows applied to 30 slices
# [ID_b66f0b20] windows applied to 40 slices
# [ID_b6768893] windows applied to 32 slices
# [ID_b6bc7cb0] windows applied to 128 slices
# [ID_b6da90a0] windows applied to 32 slices
# [ID_b789a838] windows applied to 37 slices
# [ID_b798f160] windows applied to 36 slices
# [ID_b799ed34] windows applied to 26 slices
# [ID_b844ff0f] windows applied to 39 slices
# [ID_b86a8e3a] windows applied to 35 slices
# [ID_b92b91e9] windows applied to 32 slices
# [ID_b92eb773] windows applied to 34 slices
# [ID_b9402657] windows applied to 78 slices
# [ID_b971b066] windows applied to 39 slices
# [ID_b9885431] windows applied to 38 slices
# [ID_b9c3fa70] windows applied to 74 slices
# [ID_b9c52721] windows applied to 28 slices
# [ID_b9d80416] windows applied to 44 slices
# [ID_b9df8c1c] windows applied to 28 slices
# [ID_ba27c6c5] windows applied to 40 slices
# [ID_ba281bf8] windows applied to 31 slices
# [ID_ba404dfe] windows applied to 32 slices
# [ID_bab0de02] windows applied to 32 slices
# [ID_bac02f7c] windows applied to 32 slices
# [ID_bac4bd8e] windows applied to 34 slices
# [ID_bb18211b] windows applied to 32 slices
# [ID_bb213878] windows applied to 38 slices
# [ID_bb74b508] windows applied to 31 slices
# [ID_bb7fc7d7] windows applied to 38 slices
# [ID_bbe8008c] windows applied to 33 slices
# [ID_bc330b3c] windows applied to 110 slices
# [ID_bd892a1d] windows applied to 32 slices
# [ID_bdb8ac4f] windows applied to 33 slices
# [ID_be193483] windows applied to 84 slices
# [ID_bee66b22] windows applied to 70 slices
# [ID_bf18ca4a] windows applied to 28 slices
# [ID_bf3c0b09] windows applied to 37 slices
# [ID_bf452c8a] windows applied to 32 slices
# [ID_bf60eac5] windows applied to 36 slices
# [ID_bf7186f7] windows applied to 34 slices
# [ID_bf8a3143] windows applied to 32 slices
# [ID_bfb40203] windows applied to 37 slices
# [ID_bff3b5c9] windows applied to 32 slices
# [ID_c029ca17] windows applied to 28 slices
# [ID_c0a15bcf] windows applied to 34 slices
# [ID_c0efd0a2] windows applied to 147 slices
# [ID_c114c2b8] windows applied to 32 slices
# [ID_c13afed0] windows applied to 73 slices
# [ID_c1ee6b75] windows applied to 32 slices
# [ID_c22acceb] windows applied to 70 slices
# [ID_c23b7634] windows applied to 37 slices
# [ID_c3448fcc] windows applied to 32 slices
# [ID_c39f3da7] windows applied to 60 slices
# [ID_c437190d] windows applied to 120 slices
# [ID_c4519e23] windows applied to 48 slices
# [ID_c4b3d0b0] windows applied to 38 slices
# [ID_c4fdc496] windows applied to 40 slices
# [ID_c514454e] windows applied to 28 slices
# [ID_c52cd27e] windows applied to 116 slices
# [ID_c534919a] windows applied to 32 slices
# [ID_c57f605b] windows applied to 32 slices
# [ID_c5875b7f] windows applied to 31 slices
# [ID_c589a17b] windows applied to 34 slices
# [ID_c5b9f6a9] windows applied to 147 slices
# [ID_c5fb4e6e] windows applied to 32 slices
# [ID_c646ac70] windows applied to 40 slices
# [ID_c65cd3b8] windows applied to 30 slices
# [ID_c6cc8ce8] windows applied to 40 slices
# [ID_c70477c2] windows applied to 36 slices
# [ID_c7241360] windows applied to 36 slices
# [ID_c731c09f] windows applied to 40 slices
# [ID_c76680f2] windows applied to 34 slices
# [ID_c779109b] windows applied to 32 slices
# [ID_c7b2c196] windows applied to 373 slices
# [ID_c7fe5f7f] windows applied to 60 slices
# [ID_c87e5003] windows applied to 36 slices
# [ID_c8818678] windows applied to 32 slices
# [ID_c8c30baf] windows applied to 29 slices
# [ID_c8c522e0] windows applied to 32 slices
# [ID_c917f61b] windows applied to 36 slices
# [ID_c91a524c] windows applied to 32 slices
# [ID_c9aa068c] windows applied to 75 slices
# [ID_c9b2d9b3] windows applied to 31 slices
# [ID_c9c12790] windows applied to 28 slices
# [ID_c9ff34e5] windows applied to 35 slices
# [ID_ca0cf17b] windows applied to 32 slices
# [ID_ca0e1c89] windows applied to 38 slices
# [ID_caee7821] windows applied to 36 slices
# [ID_cb852d1e] windows applied to 63 slices
# [ID_cbddaa3c] windows applied to 252 slices
# [ID_cc410877] windows applied to 36 slices
# [ID_cc92853f] windows applied to 32 slices
# [ID_ccce5f93] windows applied to 40 slices
# [ID_ccf23e97] windows applied to 38 slices
# [ID_cd2c8fad] windows applied to 40 slices
# [ID_cd441cb7] windows applied to 32 slices
# [ID_cdc9084d] windows applied to 106 slices
# [ID_ce53ede4] windows applied to 40 slices
# [ID_ce5bf1be] windows applied to 36 slices
# [ID_ce5f0b6c] windows applied to 280 slices
# [ID_ce6af3f4] windows applied to 40 slices
# [ID_ce7f7c78] windows applied to 40 slices
# [ID_cec4a149] windows applied to 64 slices
# [ID_cef99c95] windows applied to 28 slices
# [ID_cf2d6600] windows applied to 36 slices
# [ID_cf5caf75] windows applied to 42 slices
# [ID_cfa46d4d] windows applied to 30 slices
# [ID_cfa8ad3e] windows applied to 40 slices
# [ID_cfafc191] windows applied to 28 slices
# [ID_cfc4cbb1] windows applied to 41 slices
# [ID_d02f2ee1] windows applied to 30 slices
# [ID_d035a9fe] windows applied to 32 slices
# [ID_d051eff4] windows applied to 110 slices
# [ID_d1037bb6] windows applied to 33 slices
# [ID_d1150afd] windows applied to 32 slices
# [ID_d17c5f62] windows applied to 32 slices
# [ID_d1b16255] windows applied to 29 slices
# [ID_d1f11939] windows applied to 100 slices
# [ID_d212e72a] windows applied to 32 slices
# [ID_d23942c7] windows applied to 36 slices
# [ID_d2deede6] windows applied to 465 slices
# [ID_d338249d] windows applied to 40 slices
# [ID_d343e4d0] windows applied to 90 slices
# [ID_d350b969] windows applied to 40 slices
# [ID_d3f0e352] windows applied to 32 slices
# [ID_d463eef9] windows applied to 34 slices
# [ID_d4806927] windows applied to 40 slices
# [ID_d50ddcef] windows applied to 31 slices
# [ID_d559c35d] windows applied to 34 slices
# [ID_d55bd9d3] windows applied to 52 slices
# [ID_d56ba23f] windows applied to 35 slices
# [ID_d5b9400b] windows applied to 36 slices
# [ID_d6130fac] windows applied to 151 slices
# [ID_d6298d10] windows applied to 28 slices
# [ID_d63e8274] windows applied to 30 slices
# [ID_d691c6b4] windows applied to 36 slices
# [ID_d72e08f0] windows applied to 28 slices
# [ID_d79bbd03] windows applied to 28 slices
# [ID_d7aef478] windows applied to 32 slices
# [ID_d7cc90e2] windows applied to 39 slices
# [ID_d7f1f700] windows applied to 40 slices
# [ID_d807c567] windows applied to 30 slices
# [ID_d8409049] windows applied to 36 slices
# [ID_d864bdc7] windows applied to 36 slices
# [ID_d8e9de56] windows applied to 60 slices
# [ID_d978ae79] windows applied to 39 slices
# [ID_d98583a6] windows applied to 36 slices
# [ID_d9b6fcb7] windows applied to 71 slices
# [ID_d9bc5c86] windows applied to 32 slices
# [ID_d9fb84df] windows applied to 36 slices
# [ID_d9fc2e0f] windows applied to 31 slices
# [ID_da25cda3] windows applied to 44 slices
# [ID_da8db6c5] windows applied to 32 slices
# [ID_dae32cee] windows applied to 76 slices
# [ID_daebc87c] windows applied to 36 slices
# [ID_db291695] windows applied to 32 slices
# [ID_dbe3acc9] windows applied to 75 slices
# [ID_dc16f4b2] windows applied to 36 slices
# [ID_dc63bc96] windows applied to 40 slices
# [ID_dd158dca] windows applied to 32 slices
# [ID_dd2f73a3] windows applied to 32 slices
# [ID_dd477dd7] windows applied to 29 slices
# [ID_ddf83ca8] windows applied to 41 slices
# [ID_de23248b] windows applied to 44 slices
# [ID_de685255] windows applied to 32 slices
# [ID_de7cbd93] windows applied to 36 slices
# [ID_debe5ed5] windows applied to 32 slices
# [ID_ded47654] windows applied to 76 slices
# [ID_def2db8e] windows applied to 32 slices
# [ID_df089b9b] windows applied to 32 slices
# [ID_df30d45c] windows applied to 32 slices
# [ID_df4f833b] windows applied to 108 slices
# [ID_df6e2c7e] windows applied to 40 slices
# [ID_dfa39946] windows applied to 166 slices
# [ID_dfd11f1c] windows applied to 118 slices
# [ID_dff1fa85] windows applied to 68 slices
# [ID_e01005ce] windows applied to 34 slices
# [ID_e017154b] windows applied to 202 slices
# [ID_e054ecc8] windows applied to 32 slices
# [ID_e05ab819] windows applied to 31 slices
# [ID_e070edfa] windows applied to 38 slices
# [ID_e08906bc] windows applied to 36 slices
# [ID_e08b6350] windows applied to 68 slices
# [ID_e095d626] windows applied to 28 slices
# [ID_e0b4a2a2] windows applied to 42 slices
# [ID_e0fd4285] windows applied to 41 slices
# [ID_e10d19e2] windows applied to 36 slices
# [ID_e1be8ce4] windows applied to 100 slices
# [ID_e1f3e80e] windows applied to 30 slices
# [ID_e228ec60] windows applied to 29 slices
# [ID_e23364fa] windows applied to 38 slices
# [ID_e2a5a300] windows applied to 40 slices
# [ID_e2d4665c] windows applied to 46 slices
# [ID_e34ca49d] windows applied to 38 slices
# [ID_e35cedea] windows applied to 44 slices
# [ID_e393f193] windows applied to 30 slices
# [ID_e39c9932] windows applied to 67 slices
# [ID_e3ba5cf7] windows applied to 60 slices
# [ID_e4488e09] windows applied to 192 slices
# [ID_e48463fa] windows applied to 32 slices
# [ID_e4ffd781] windows applied to 31 slices
# [ID_e566ef9b] windows applied to 32 slices
# [ID_e5dc2ecf] windows applied to 43 slices
# [ID_e60060d0] windows applied to 42 slices
# [ID_e6722bcf] windows applied to 111 slices
# [ID_e6932bed] windows applied to 44 slices
# [ID_e715684e] windows applied to 40 slices
# [ID_e731a1c8] windows applied to 71 slices
# [ID_e79c618e] windows applied to 36 slices
# [ID_e7a14bf5] windows applied to 35 slices
# [ID_e7e34e9e] windows applied to 31 slices
# [ID_e7fb07db] windows applied to 36 slices
# [ID_e83511c4] windows applied to 76 slices
# [ID_e867fe7a] windows applied to 28 slices
# [ID_e874b8c9] windows applied to 220 slices
# [ID_e8815d89] windows applied to 32 slices
# [ID_e8c8d283] windows applied to 32 slices
# [ID_e8fe82da] windows applied to 132 slices
# [ID_e9b05f1c] windows applied to 36 slices
# [ID_ea1f8876] windows applied to 33 slices
# [ID_eaf65d0e] windows applied to 108 slices
# [ID_eb383c7a] windows applied to 28 slices
# [ID_eb7ce28a] windows applied to 32 slices
# [ID_eba9f1a7] windows applied to 44 slices
# [ID_ecd7e320] windows applied to 40 slices
# [ID_ecd8d7ec] windows applied to 32 slices
# [ID_ed056f84] windows applied to 52 slices
# [ID_ed7be44c] windows applied to 36 slices
# [ID_edc1a834] windows applied to 32 slices
# [ID_ee150dc0] windows applied to 30 slices
# [ID_ee20e4ba] windows applied to 34 slices
# [ID_ee7ba95f] windows applied to 76 slices
# [ID_eeb4ec36] windows applied to 30 slices
# [ID_eed25553] windows applied to 124 slices
# [ID_eedfa085] windows applied to 40 slices
# [ID_eee876b5] windows applied to 40 slices
# [ID_eef431b9] windows applied to 30 slices
# [ID_ef7dc5c1] windows applied to 34 slices
# [ID_f038ceda] windows applied to 74 slices
# [ID_f07588df] windows applied to 148 slices
# [ID_f0c08bc4] windows applied to 33 slices
# [ID_f0d7fb4f] windows applied to 84 slices
# [ID_f0f75643] windows applied to 32 slices
# [ID_f1079266] windows applied to 37 slices
# [ID_f1635079] windows applied to 37 slices
# [ID_f1e247fb] windows applied to 36 slices
# [ID_f204d8f9] windows applied to 42 slices
# [ID_f27d46d1] windows applied to 32 slices
# [ID_f2939e11] windows applied to 40 slices
# [ID_f2abe525] windows applied to 40 slices
# [ID_f2e6e5b4] windows applied to 32 slices
# [ID_f365aa20] windows applied to 36 slices
# [ID_f39a4d5d] windows applied to 32 slices
# [ID_f3ca99fb] windows applied to 28 slices
# [ID_f3e41f0c] windows applied to 36 slices
# [ID_f4212d9e] windows applied to 35 slices
# [ID_f498df47] windows applied to 40 slices
# [ID_f4bf153b] windows applied to 34 slices
# [ID_f500d8aa] windows applied to 28 slices
# [ID_f500f072] windows applied to 104 slices
# [ID_f54e57db] windows applied to 24 slices
# [ID_f55ca0f3] windows applied to 30 slices
# [ID_f55e66d5] windows applied to 28 slices
# [ID_f5643190] windows applied to 288 slices
# [ID_f59ee23e] windows applied to 33 slices
# [ID_f5e85730] windows applied to 32 slices
# [ID_f6001093] windows applied to 38 slices
# [ID_f62da880] windows applied to 32 slices
# [ID_f64723ab] windows applied to 32 slices
# [ID_f651f957] windows applied to 70 slices
# [ID_f742a58e] windows applied to 64 slices
# [ID_f772d97c] windows applied to 41 slices
# [ID_f77f2422] windows applied to 80 slices
# [ID_f7995ea2] windows applied to 56 slices
# [ID_f7c5b11f] windows applied to 64 slices
# [ID_f7d77307] windows applied to 30 slices
# [ID_f8453085] windows applied to 40 slices
# [ID_f87433b7] windows applied to 34 slices
# [ID_f8da191e] windows applied to 32 slices
# [ID_f8e8e3b1] windows applied to 45 slices
# [ID_f928b8d1] windows applied to 32 slices
# [ID_f995726a] windows applied to 48 slices
# [ID_f9f79ffe] windows applied to 33 slices
# [ID_fb2f0041] windows applied to 30 slices
# [ID_fbc74834] windows applied to 32 slices
# [ID_fc504748] windows applied to 40 slices
# [ID_fc69f9ce] windows applied to 32 slices
# [ID_fc9442d1] windows applied to 160 slices
# [ID_fcbf2006] windows applied to 32 slices
# [ID_fd8ab0a0] windows applied to 108 slices
# [ID_fe709f1f] windows applied to 32 slices
# [ID_feb83fb3] windows applied to 187 slices
# [ID_fec357c9] windows applied to 32 slices
# [ID_fec504bc] windows applied to 32 slices
# [ID_fed25cd9] windows applied to 66 slices
# [ID_ff2c88f6] windows applied to 40 slices
# [ID_ff40fe30] windows applied to 32 slices
# [ID_ff5e6c57] windows applied to 38 slices
# [ID_ffc99fd6] windows applied to 92 slices
# [ID_ffd91f66] windows applied to 32 slices
# [patient_images_500_1000] no sorted DICOMs found, skipping
